# %% [markdown]
# - eda_20250211 で作った drop_cols_d 以外の特徴量を使って学習する

# %%
# %load_ext autoreload

# %%
# %autoreload 2

import os
import sys
import json
import gc
import pickle 


from numerapi import NumerAPI
from numerai_tools.scoring import numerai_corr, correlation_contribution

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

import lightgbm as lgb

sys.path.append("../")
from src.model import MLModel, LightGBMModel
from src.validation import caluculate_metrics 
from src.featuring import add_feature

# %% [markdown]
# # Config

# %%
class cfg:
    exp = "exp017"
    dataset_path = "../dataset/v5.0"
    feature_set = "all"
    valid_ratio = 0.2
    threshold_corr = 0.90
    
    model_params = {
        "objective": "regression",
        "metric": "l2",
        "n_estimators": 2000,
        "max_depth": 5,
        "learning_rate": 0.01,
        "feature_fraction": 0.1,
        "seed": 42,
    }

# %%
with open("./eda_20250211/feature_groups_drop_cols.json", "r") as f:
    drop_cols_d = json.load(f)
# print(drop_cols_d)
drop_cols = []
for k, v in drop_cols_d.items():
    drop_cols += v
print(len(drop_cols))
# Out:
# 1348

# %%
# 実験用フォルダ作成    
os.makedirs(cfg.exp, exist_ok=True)

# 辞書形式に変換して保存 (推論時に使用する)
cfg_dict = {attr: getattr(cfg, attr) for attr in dir(cfg) if not attr.startswith("__") and not callable(getattr(cfg, attr))}
config_file = os.path.join(cfg.exp, "training_config.json")
with open(config_file, "w") as f:
    json.dump(cfg_dict, f, indent=4)

with open(f"{cfg.dataset_path}/features.json", "r") as f:
    feature_metadata = json.load(f)

# print(feature_metadata.keys())
feature_sets = feature_metadata["feature_sets"]
# print(feature_sets.keys())
feature_set = feature_sets[cfg.feature_set]
feature_set = [col for col in feature_set if col not in drop_cols]
print(f"feature col length: {len(feature_set)}")



targets = feature_metadata["targets"]
targets = ["target", "target_agnes_20"]
# Out:
# feature col length: 1098

# %% [markdown]
# # Load Data

# %%
train = pd.read_parquet(
    f"{cfg.dataset_path}/train.parquet",
    columns=["era"] + feature_set + targets
)

valid = pd.read_parquet(
    f"{cfg.dataset_path}/validation.parquet",
    columns=["era"] + feature_set + targets
    
)

print(train.shape)
display(train.head(2))

print(valid.shape)
display(valid.head(2))
# Out:
# (2746270, 1101)
#                    era  feature_abrasive_forcipate_crewel  \
# id
# n0007b5abb0c3a25  0001                                  2
# n003bba8a98662e4  0001                                  2
#
#                   feature_accadian_pledged_bore  \
# id
# n0007b5abb0c3a25                              2
# n003bba8a98662e4                              2
#
#                   feature_acclamatory_draconian_view  \
# id
# n0007b5abb0c3a25                                   2
# n003bba8a98662e4                                   1
#
#                   feature_according_tied_bedlam  \
# id
# n0007b5abb0c3a25                              2
# n003bba8a98662e4                              2
#
#                   feature_acetose_permeated_irregular  \
# id
# n0007b5abb0c3a25                                    2
# n003bba8a98662e4                                    2
#
#                   feature_acheulian_constrainable_ahriman  \
# id
# n0007b5abb0c3a25                                        2
# n003bba8a98662e4                                        2
#
#                   feature_acknowledged_anteorbital_bilker  \
# id
# n0007b5abb0c3a25                                        2
# n003bba8a98662e4                                        2
#
#                   feature_acrylic_gallic_wine  \
# id
# n0007b5abb0c3a25                            2
# n003bba8a98662e4                            2
#
#                   feature_adaptative_nasal_monastery  ...  \
# id                                                    ...
# n0007b5abb0c3a25                                   2  ...
# n003bba8a98662e4                                   2  ...
#
#                   feature_zincoid_supreme_brummell  \
# id
# n0007b5abb0c3a25                                 2
# n003bba8a98662e4                                 2
#
#                   feature_zincy_cirrhotic_josh  \
# id
# n0007b5abb0c3a25                             4
# n003bba8a98662e4                             0
#
#                   feature_zippy_trine_diffraction  \
# id
# n0007b5abb0c3a25                                3
# n003bba8a98662e4                                0
#
#                   feature_zonal_snuffly_chemism  \
# id
# n0007b5abb0c3a25                              2
# n003bba8a98662e4                              2
#
#                   feature_zoological_peristomial_scute  \
# id
# n0007b5abb0c3a25                                     2
# n003bba8a98662e4                                     2
#
#                   feature_zygotic_middlebrow_caribbean  \
# id
# n0007b5abb0c3a25                                     1
# n003bba8a98662e4                                     0
#
#                   feature_zymolytic_intertidal_privet  \
# id
# n0007b5abb0c3a25                                    0
# n003bba8a98662e4                                    0
#
#                   feature_zymotic_windswept_cooky  target  target_agnes_20
# id
# n0007b5abb0c3a25                                0    0.25             0.25
# n003bba8a98662e4                                0    0.25             0.25
#
# [2 rows x 1101 columns]
# (3577827, 1101)
#                    era  feature_abrasive_forcipate_crewel  \
# id
# n000101811a8a843  0575                                  2
# n001e1318d5072ac  0575                                  1
#
#                   feature_accadian_pledged_bore  \
# id
# n000101811a8a843                              2
# n001e1318d5072ac                              3
#
#                   feature_acclamatory_draconian_view  \
# id
# n000101811a8a843                                   0
# n001e1318d5072ac                                   1
#
#                   feature_according_tied_bedlam  \
# id
# n000101811a8a843                              2
# n001e1318d5072ac                              4
#
#                   feature_acetose_permeated_irregular  \
# id
# n000101811a8a843                                    2
# n001e1318d5072ac                                    3
#
#                   feature_acheulian_constrainable_ahriman  \
# id
# n000101811a8a843                                        3
# n001e1318d5072ac                                        3
#
#                   feature_acknowledged_anteorbital_bilker  \
# id
# n000101811a8a843                                        2
# n001e1318d5072ac                                        3
#
#                   feature_acrylic_gallic_wine  \
# id
# n000101811a8a843                            0
# n001e1318d5072ac                            0
#
#                   feature_adaptative_nasal_monastery  ...  \
# id                                                    ...
# n000101811a8a843                                   0  ...
# n001e1318d5072ac                                   4  ...
#
#                   feature_zincoid_supreme_brummell  \
# id
# n000101811a8a843                                 2
# n001e1318d5072ac                                 4
#
#                   feature_zincy_cirrhotic_josh  \
# id
# n000101811a8a843                             4
# n001e1318d5072ac                             1
#
#                   feature_zippy_trine_diffraction  \
# id
# n000101811a8a843                                2
# n001e1318d5072ac                                1
#
#                   feature_zonal_snuffly_chemism  \
# id
# n000101811a8a843                              0
# n001e1318d5072ac                              0
#
#                   feature_zoological_peristomial_scute  \
# id
# n000101811a8a843                                     0
# n001e1318d5072ac                                     1
#
#                   feature_zygotic_middlebrow_caribbean  \
# id
# n000101811a8a843                                     0
# n001e1318d5072ac                                     3
#
#                   feature_zymolytic_intertidal_privet  \
# id
# n000101811a8a843                                    1
# n001e1318d5072ac                                    4
#
#                   feature_zymotic_windswept_cooky  target  target_agnes_20
# id
# n000101811a8a843                                0    0.75             0.75
# n001e1318d5072ac                                3    0.00             0.00
#
# [2 rows x 1101 columns]

# %% [markdown]
# # Preprocess

# %%
# 学習データを増やす (train, valid を合体してから分ける)
print(train.shape, valid.shape)

data = pd.concat([train, valid])
display(data.tail())
# Out:
# (2746270, 1101) (3577827, 1101)
#                    era  feature_abrasive_forcipate_crewel  \
# id
# nffce425c89dc5da  1153                                  4
# nffd4e7b55827375  1153                                  2
# nffea643830509bf  1153                                  3
# nffea66c53d0aebe  1153                                  1
# nfff2966f1f157af  1153                                  1
#
#                   feature_accadian_pledged_bore  \
# id
# nffce425c89dc5da                              1
# nffd4e7b55827375                              1
# nffea643830509bf                              2
# nffea66c53d0aebe                              1
# nfff2966f1f157af                              3
#
#                   feature_acclamatory_draconian_view  \
# id
# nffce425c89dc5da                                   4
# nffd4e7b55827375                                   4
# nffea643830509bf                                   4
# nffea66c53d0aebe                                   0
# nfff2966f1f157af                                   3
#
#                   feature_according_tied_bedlam  \
# id
# nffce425c89dc5da                              2
# nffd4e7b55827375                              2
# nffea643830509bf                              4
# nffea66c53d0aebe                              0
# nfff2966f1f157af                              2
#
#                   feature_acetose_permeated_irregular  \
# id
# nffce425c89dc5da                                    0
# nffd4e7b55827375                                    2
# nffea643830509bf                                    4
# nffea66c53d0aebe                                    3
# nfff2966f1f157af                                    4
#
#                   feature_acheulian_constrainable_ahriman  \
# id
# nffce425c89dc5da                                        4
# nffd4e7b55827375                                        2
# nffea643830509bf                                        3
# nffea66c53d0aebe                                        2
# nfff2966f1f157af                                        0
#
#                   feature_acknowledged_anteorbital_bilker  \
# id
# nffce425c89dc5da                                        0
# nffd4e7b55827375                                        1
# nffea643830509bf                                        2
# nffea66c53d0aebe                                        1
# nfff2966f1f157af                                        0
#
#                   feature_acrylic_gallic_wine  \
# id
# nffce425c89dc5da                            4
# nffd4e7b55827375                            4
# nffea643830509bf                            2
# nffea66c53d0aebe                            0
# nfff2966f1f157af                            1
#
#                   feature_adaptative_nasal_monastery  ...  \
# id                                                    ...
# nffce425c89dc5da                                   1  ...
# nffd4e7b55827375                                   3  ...
# nffea643830509bf                                   3  ...
# nffea66c53d0aebe                                   2  ...
# nfff2966f1f157af                                   3  ...
#
#                   feature_zincoid_supreme_brummell  \
# id
# nffce425c89dc5da                                 2
# nffd4e7b55827375                                 4
# nffea643830509bf                                 0
# nffea66c53d0aebe                                 1
# nfff2966f1f157af                                 0
#
#                   feature_zincy_cirrhotic_josh  \
# id
# nffce425c89dc5da                             2
# nffd4e7b55827375                             0
# nffea643830509bf                             4
# nffea66c53d0aebe                             2
# nfff2966f1f157af                             0
#
#                   feature_zippy_trine_diffraction  \
# id
# nffce425c89dc5da                                4
# nffd4e7b55827375                                2
# nffea643830509bf                                4
# nffea66c53d0aebe                                2
# nfff2966f1f157af                                3
#
#                   feature_zonal_snuffly_chemism  \
# id
# nffce425c89dc5da                              0
# nffd4e7b55827375                              1
# nffea643830509bf                              2
# nffea66c53d0aebe                              2
# nfff2966f1f157af                              2
#
#                   feature_zoological_peristomial_scute  \
# id
# nffce425c89dc5da                                     0
# nffd4e7b55827375                                     3
# nffea643830509bf                                     2
# nffea66c53d0aebe                                     3
# nfff2966f1f157af                                     4
#
#                   feature_zygotic_middlebrow_caribbean  \
# id
# nffce425c89dc5da                                     3
# nffd4e7b55827375                                     0
# nffea643830509bf                                     4
# nffea66c53d0aebe                                     2
# nfff2966f1f157af                                     0
#
#                   feature_zymolytic_intertidal_privet  \
# id
# nffce425c89dc5da                                    3
# nffd4e7b55827375                                    4
# nffea643830509bf                                    3
# nffea66c53d0aebe                                    2
# nfff2966f1f157af                                    0
#
#                   feature_zymotic_windswept_cooky  target  target_agnes_20
# id
# nffce425c89dc5da                                4     NaN              NaN
# nffd4e7b55827375                                0     NaN              NaN
# nffea643830509bf                                0     NaN              NaN
# nffea66c53d0aebe                                2     NaN              NaN
# nfff2966f1f157af                                0     NaN              NaN
#
# [5 rows x 1101 columns]

# %%
print(data.shape)

# data = add_feature(data)
print(data.shape)
# Out:
# (6324097, 1101)
# (6324097, 1101)

# %%
# era 単位で分ける
all_era = data["era"].unique()
n_idx = int(len(all_era) * (1 - cfg.valid_ratio))
print(data.shape)
print(n_idx)

train_era = all_era[:n_idx]
cond_train = data["era"].isin(train_era)
train, valid = data.loc[cond_train], data.loc[~cond_train]

print(train.shape, valid.shape)

del data; gc.collect()
# Out:
# (6324097, 1101)
# 922
# (4817566, 1101) (1506531, 1101)
# 0

# %%
train["era_int"] = train["era"].astype(int)

# %% [markdown]
# # Training

# %%
features = feature_set + [col for col in train.columns if "per_era" in col]
print(len(features))
# Out:
# 1098

# %%
train = train.reset_index(drop=True)

# %%
models = []

for target in targets:
    print("=" * 64)
    print("target: ", target)
    for i in range(4):
        cond_train = (train["era_int"] % 4 == i) & (~train[target].isnull())
        cond_valid = ~valid[target].isnull()
        tmp_train = train[cond_train]
        tmp_valid = valid[cond_valid]

        model = LightGBMModel(
            model_params=cfg.model_params,
        )
        model.train(
            tmp_train[features],
            tmp_train[target],
            eval_set=(tmp_valid[features], tmp_valid[target]),
            early_stopping_rounds=10
        )
        models.append(model)
        model.save_model(os.path.join(cfg.exp, f"model_{i}_{target}.pkl"))
        del tmp_train, tmp_valid; gc.collect()

with open(os.path.join(cfg.exp, "feature.pkl"), "wb") as f:
     pickle.dump(features, f)
# Out:
# ================================================================
# target:  target
# /home/kouya-takahashi/.local/lib/python3.9/site-packages/lightgbm/engine.py:204: UserWarning: Found `n_estimators` in params. Will use it instead of argument
#   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# [LightGBM] [Warning] Provided parameters constrain tree depth (max_depth=5) without explicitly setting 'num_leaves'. This can lead to underfitting. To resolve this warning, pass 'num_leaves' (<=32) in params. Alternatively, pass (max_depth=-1) and just use 'num_leaves' to constrain model complexity.
# [LightGBM] [Warning] Provided parameters constrain tree depth (max_depth=5) without explicitly setting 'num_leaves'. This can lead to underfitting. To resolve this warning, pass 'num_leaves' (<=32) in params. Alternatively, pass (max_depth=-1) and just use 'num_leaves' to constrain model complexity.
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.032302 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 5490
# [LightGBM] [Info] Number of data points in the train set: 1202054, number of used features: 1098
# [LightGBM] [Warning] Provided parameters constrain tree depth (max_depth=5) without explicitly setting 'num_leaves'. This can lead to underfitting. To resolve this warning, pass 'num_leaves' (<=32) in params. Alternatively, pass (max_depth=-1) and just use 'num_leaves' to constrain model complexity.
# [LightGBM] [Info] Start training from score 0.500031
# Training until validation scores don't improve for 10 rounds
# Early stopping, best iteration is:
# [447]	valid_0's l2: 0.0498165
# /home/kouya-takahashi/.local/lib/python3.9/site-packages/lightgbm/engine.py:204: UserWarning: Found `n_estimators` in params. Will use it instead of argument
#   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# [LightGBM] [Warning] Provided parameters constrain tree depth (max_depth=5) without explicitly setting 'num_leaves'. This can lead to underfitting. To resolve this warning, pass 'num_leaves' (<=32) in params. Alternatively, pass (max_depth=-1) and just use 'num_leaves' to constrain model complexity.
# [LightGBM] [Warning] Provided parameters constrain tree depth (max_depth=5) without explicitly setting 'num_leaves'. This can lead to underfitting. To resolve this warning, pass 'num_leaves' (<=32) in params. Alternatively, pass (max_depth=-1) and just use 'num_leaves' to constrain model complexity.
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.031775 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 5490
# [LightGBM] [Info] Number of data points in the train set: 1205900, number of used features: 1098
# [LightGBM] [Warning] Provided parameters constrain tree depth (max_depth=5) without explicitly setting 'num_leaves'. This can lead to underfitting. To resolve this warning, pass 'num_leaves' (<=32) in params. Alternatively, pass (max_depth=-1) and just use 'num_leaves' to constrain model complexity.
# [LightGBM] [Info] Start training from score 0.500020
# Training until validation scores don't improve for 10 rounds
# Early stopping, best iteration is:
# [553]	valid_0's l2: 0.0498154
# /home/kouya-takahashi/.local/lib/python3.9/site-packages/lightgbm/engine.py:204: UserWarning: Found `n_estimators` in params. Will use it instead of argument
#   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# [LightGBM] [Warning] Provided parameters constrain tree depth (max_depth=5) without explicitly setting 'num_leaves'. This can lead to underfitting. To resolve this warning, pass 'num_leaves' (<=32) in params. Alternatively, pass (max_depth=-1) and just use 'num_leaves' to constrain model complexity.
# [LightGBM] [Warning] Provided parameters constrain tree depth (max_depth=5) without explicitly setting 'num_leaves'. This can lead to underfitting. To resolve this warning, pass 'num_leaves' (<=32) in params. Alternatively, pass (max_depth=-1) and just use 'num_leaves' to constrain model complexity.
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.031974 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 5490
# [LightGBM] [Info] Number of data points in the train set: 1207776, number of used features: 1098
# [LightGBM] [Warning] Provided parameters constrain tree depth (max_depth=5) without explicitly setting 'num_leaves'. This can lead to underfitting. To resolve this warning, pass 'num_leaves' (<=32) in params. Alternatively, pass (max_depth=-1) and just use 'num_leaves' to constrain model complexity.
# [LightGBM] [Info] Start training from score 0.500018
# Training until validation scores don't improve for 10 rounds
# Early stopping, best iteration is:
# [659]	valid_0's l2: 0.049815
# /home/kouya-takahashi/.local/lib/python3.9/site-packages/lightgbm/engine.py:204: UserWarning: Found `n_estimators` in params. Will use it instead of argument
#   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# [LightGBM] [Warning] Provided parameters constrain tree depth (max_depth=5) without explicitly setting 'num_leaves'. This can lead to underfitting. To resolve this warning, pass 'num_leaves' (<=32) in params. Alternatively, pass (max_depth=-1) and just use 'num_leaves' to constrain model complexity.
# [LightGBM] [Warning] Provided parameters constrain tree depth (max_depth=5) without explicitly setting 'num_leaves'. This can lead to underfitting. To resolve this warning, pass 'num_leaves' (<=32) in params. Alternatively, pass (max_depth=-1) and just use 'num_leaves' to constrain model complexity.
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.031613 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 5490
# [LightGBM] [Info] Number of data points in the train set: 1201836, number of used features: 1098
# [LightGBM] [Warning] Provided parameters constrain tree depth (max_depth=5) without explicitly setting 'num_leaves'. This can lead to underfitting. To resolve this warning, pass 'num_leaves' (<=32) in params. Alternatively, pass (max_depth=-1) and just use 'num_leaves' to constrain model complexity.
# [LightGBM] [Info] Start training from score 0.500023
# Training until validation scores don't improve for 10 rounds
# Early stopping, best iteration is:
# [492]	valid_0's l2: 0.0498155
# ================================================================
# target:  target_agnes_20
# /home/kouya-takahashi/.local/lib/python3.9/site-packages/lightgbm/engine.py:204: UserWarning: Found `n_estimators` in params. Will use it instead of argument
#   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# [LightGBM] [Warning] Provided parameters constrain tree depth (max_depth=5) without explicitly setting 'num_leaves'. This can lead to underfitting. To resolve this warning, pass 'num_leaves' (<=32) in params. Alternatively, pass (max_depth=-1) and just use 'num_leaves' to constrain model complexity.
# [LightGBM] [Warning] Provided parameters constrain tree depth (max_depth=5) without explicitly setting 'num_leaves'. This can lead to underfitting. To resolve this warning, pass 'num_leaves' (<=32) in params. Alternatively, pass (max_depth=-1) and just use 'num_leaves' to constrain model complexity.
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.031596 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 5490
# [LightGBM] [Info] Number of data points in the train set: 1202054, number of used features: 1098
# [LightGBM] [Warning] Provided parameters constrain tree depth (max_depth=5) without explicitly setting 'num_leaves'. This can lead to underfitting. To resolve this warning, pass 'num_leaves' (<=32) in params. Alternatively, pass (max_depth=-1) and just use 'num_leaves' to constrain model complexity.
# [LightGBM] [Info] Start training from score 0.500054
# Training until validation scores don't improve for 10 rounds
# Early stopping, best iteration is:
# [475]	valid_0's l2: 0.0496152
# /home/kouya-takahashi/.local/lib/python3.9/site-packages/lightgbm/engine.py:204: UserWarning: Found `n_estimators` in params. Will use it instead of argument
#   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# [LightGBM] [Warning] Provided parameters constrain tree depth (max_depth=5) without explicitly setting 'num_leaves'. This can lead to underfitting. To resolve this warning, pass 'num_leaves' (<=32) in params. Alternatively, pass (max_depth=-1) and just use 'num_leaves' to constrain model complexity.
# [LightGBM] [Warning] Provided parameters constrain tree depth (max_depth=5) without explicitly setting 'num_leaves'. This can lead to underfitting. To resolve this warning, pass 'num_leaves' (<=32) in params. Alternatively, pass (max_depth=-1) and just use 'num_leaves' to constrain model complexity.
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.031698 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 5490
# [LightGBM] [Info] Number of data points in the train set: 1205900, number of used features: 1098
# [LightGBM] [Warning] Provided parameters constrain tree depth (max_depth=5) without explicitly setting 'num_leaves'. This can lead to underfitting. To resolve this warning, pass 'num_leaves' (<=32) in params. Alternatively, pass (max_depth=-1) and just use 'num_leaves' to constrain model complexity.
# [LightGBM] [Info] Start training from score 0.500113
# Training until validation scores don't improve for 10 rounds
# Early stopping, best iteration is:
# [466]	valid_0's l2: 0.0496112
# /home/kouya-takahashi/.local/lib/python3.9/site-packages/lightgbm/engine.py:204: UserWarning: Found `n_estimators` in params. Will use it instead of argument
#   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# [LightGBM] [Warning] Provided parameters constrain tree depth (max_depth=5) without explicitly setting 'num_leaves'. This can lead to underfitting. To resolve this warning, pass 'num_leaves' (<=32) in params. Alternatively, pass (max_depth=-1) and just use 'num_leaves' to constrain model complexity.
# [LightGBM] [Warning] Provided parameters constrain tree depth (max_depth=5) without explicitly setting 'num_leaves'. This can lead to underfitting. To resolve this warning, pass 'num_leaves' (<=32) in params. Alternatively, pass (max_depth=-1) and just use 'num_leaves' to constrain model complexity.
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.031730 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 5490
# [LightGBM] [Info] Number of data points in the train set: 1207776, number of used features: 1098
# [LightGBM] [Warning] Provided parameters constrain tree depth (max_depth=5) without explicitly setting 'num_leaves'. This can lead to underfitting. To resolve this warning, pass 'num_leaves' (<=32) in params. Alternatively, pass (max_depth=-1) and just use 'num_leaves' to constrain model complexity.
# [LightGBM] [Info] Start training from score 0.500109
# Training until validation scores don't improve for 10 rounds
# Early stopping, best iteration is:
# [467]	valid_0's l2: 0.0496174
# /home/kouya-takahashi/.local/lib/python3.9/site-packages/lightgbm/engine.py:204: UserWarning: Found `n_estimators` in params. Will use it instead of argument
#   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# [LightGBM] [Warning] Provided parameters constrain tree depth (max_depth=5) without explicitly setting 'num_leaves'. This can lead to underfitting. To resolve this warning, pass 'num_leaves' (<=32) in params. Alternatively, pass (max_depth=-1) and just use 'num_leaves' to constrain model complexity.
# [LightGBM] [Warning] Provided parameters constrain tree depth (max_depth=5) without explicitly setting 'num_leaves'. This can lead to underfitting. To resolve this warning, pass 'num_leaves' (<=32) in params. Alternatively, pass (max_depth=-1) and just use 'num_leaves' to constrain model complexity.
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.031656 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 5490
# [LightGBM] [Info] Number of data points in the train set: 1201836, number of used features: 1098
# [LightGBM] [Warning] Provided parameters constrain tree depth (max_depth=5) without explicitly setting 'num_leaves'. This can lead to underfitting. To resolve this warning, pass 'num_leaves' (<=32) in params. Alternatively, pass (max_depth=-1) and just use 'num_leaves' to constrain model complexity.
# [LightGBM] [Info] Start training from score 0.500072
# Training until validation scores don't improve for 10 rounds
# Early stopping, best iteration is:
# [479]	valid_0's l2: 0.0496213

# %%
print(len(models))

for model in models:
    model.visualize_learning_curve()
    model.visualize_feature_importance()
    break
# Out:
# 8

# %% [markdown]
# # Validation

# %%
preds = np.zeros(len(valid))

for model in models:
    preds += model.predict(valid[features]) / len(models)

valid["pred"] = preds
caluculate_metrics(cfg.dataset_path, valid)
# Out:
# (   corr_mean  corr_std  corr_shape  corr_max_drawdown  mmc_mean   mmc_std  \
#  0    0.01938  0.020549    0.943136           0.104084 -0.000463  0.008692
#
#     mmc_shape  mmc_max_drawdown  bmc_mean   bmc_std  bmc_shape  \
#  0  -0.053222          0.058467  0.001023  0.012772   0.080068
#
#     bmc_max_drawdown
#  0          0.469207  ,
#            pred
#  era
#  0923  0.030044
#  0924  0.041437
#  0925  0.026359
#  0926  0.023110
#  0927  0.026253
#  ...        ...
#  1144  0.042637
#  1145  0.029513
#  1146  0.027432
#  1147  0.032712
#  1148  0.027931
#
#  [226 rows x 1 columns],
#            pred
#  era
#  0923  0.010586
#  0924  0.010004
#  0925 -0.000758
#  0926 -0.008433
#  0927  0.001342
#  ...        ...
#  1144  0.011444
#  1145  0.018695
#  1146  0.021294
#  1147  0.016320
#  1148  0.009332
#
#  [226 rows x 1 columns],
#            pred
#  era
#  1133 -0.005042
#  1134 -0.009662
#  1135 -0.010701
#  1136 -0.003204
#  1137 -0.008850
#  1138 -0.009684
#  1139 -0.009063
#  1140 -0.000767
#  1141 -0.000115
#  1142 -0.006420
#  1143  0.007123
#  1144  0.005164
#  1145  0.012755
#  1146  0.014240
#  1147  0.010917
#  1148  0.005909)
