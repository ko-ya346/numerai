# %%
import pandas as pd
from numerapi import NumerAPI

# %%
napi = NumerAPI("CYW4VVIEGW4KOCMPPEKTMI3WQLSGKURT", "7MITLDYY2BNKI4UH6EQ64QLZSWYADTEAHASZ6BZH2QWRTVXAH375AIFIPSL7LIJY")

# %%
print(napi.check_new_round())
print(napi.check_round_open())
print(napi.get_current_round())
print(napi.get_models())
# Out:
# True
# True
# 926
# {'ko_ya346_first': '231db7c8-8c83-4026-b87a-b69a29ac7fdf', 'ko_ya346_2nd': '457fb044-c0bd-4124-859b-f41939e45f13'}

# %%
df1 = pd.read_parquet("../../dataset/v5.0/live.parquet")
display(df1.head())
# Out:
#                  era data_type  feature_shaded_hallucinatory_dactylology
# id
# n0004068164d5c60   X      live                                         3  \
# n0004ae2fc8cf3a4   X      live                                         2
# n0016366a76090cc   X      live                                         1
# n002888df4c14e00   X      live                                         3
# n0049fc4a55eafb3   X      live                                         2
#
#                   feature_itinerant_hexahedral_photoengraver
# id
# n0004068164d5c60                                           4  \
# n0004ae2fc8cf3a4                                           3
# n0016366a76090cc                                           1
# n002888df4c14e00                                           2
# n0049fc4a55eafb3                                           4
#
#                   feature_prudent_pileate_oven
# id
# n0004068164d5c60                             4  \
# ...

# %%
df2 = pd.read_parquet("../../submissions/live.parquet")
display(df2.head())
# Out:
#                  era data_type  feature_shaded_hallucinatory_dactylology
# id
# n0004068164d5c60   X      live                                         3  \
# n0004ae2fc8cf3a4   X      live                                         2
# n0016366a76090cc   X      live                                         1
# n002888df4c14e00   X      live                                         3
# n0049fc4a55eafb3   X      live                                         2
#
#                   feature_itinerant_hexahedral_photoengraver
# id
# n0004068164d5c60                                           4  \
# n0004ae2fc8cf3a4                                           3
# n0016366a76090cc                                           1
# n002888df4c14e00                                           2
# n0049fc4a55eafb3                                           4
#
#                   feature_prudent_pileate_oven
# id
# n0004068164d5c60                             4  \
# ...

# %%
df1 == df2
# Out:
#                    era  data_type  feature_shaded_hallucinatory_dactylology
# id
# n0004068164d5c60  True       True                                      True  \
# n0004ae2fc8cf3a4  True       True                                      True
# n0016366a76090cc  True       True                                      True
# n002888df4c14e00  True       True                                      True
# n0049fc4a55eafb3  True       True                                      True
# ...                ...        ...                                       ...
# nffc2f0a16c8cdfe  True       True                                      True
# nffca352912f7506  True       True                                      True
# nffd47e9209fc082  True       True                                      True
# nffed97838e2628e  True       True                                      True
# nfff3b34dd260073  True       True                                      True
#
# ...
