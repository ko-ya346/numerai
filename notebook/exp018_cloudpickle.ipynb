# %% [markdown]
# # cloudpickle 使えるようにする
# - 自作モジュールを取り込む方法があるらしい

# %%
import os
import sys
import json
import gc
import pickle 
import cloudpickle

from numerapi import NumerAPI

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

import lightgbm as lgb

sys.path.append("../")
import src.model as src_model
# import src.validation as src_validation

# %%
cloudpickle.register_pickle_by_value(src_model)
# cloudpickle.register_pickle_by_value(src_validation)

# %% [markdown]
# # Config

# %%
class cfg:
    exp = "exp018"
    data_version = "v5.0"
    dataset_path = f"../dataset/{data_version}"
    feature_set = "small"
    valid_ratio = None
    
    model_params = {
        "objective": "regression",
        "metric": "l2",
        "n_estimators": 2000,
        "max_depth": 5,
        "learning_rate": 0.01,
        "feature_fraction": 0.1,
        "seed": 42,
    }

napi = NumerAPI()

# %%
# 実験用フォルダ作成    
os.makedirs(cfg.exp, exist_ok=True)

# 辞書形式に変換して保存 (推論時に使用する)
cfg_dict = {attr: getattr(cfg, attr) for attr in dir(cfg) if not attr.startswith("__") and not callable(getattr(cfg, attr))}
config_file = os.path.join(cfg.exp, "training_config.json")
with open(config_file, "w") as f:
    json.dump(cfg_dict, f, indent=4)

with open(f"{cfg.dataset_path}/features.json", "r") as f:
    feature_metadata = json.load(f)

# print(feature_metadata.keys())
feature_sets = feature_metadata["feature_sets"]
# print(feature_sets.keys())
feature_set = feature_sets[cfg.feature_set][:80]
print(f"feature col length: {len(feature_set)}")


targets = feature_metadata["targets"]
targets = ["target", "target_agnes_20"]
# Out:
# feature col length: 42

# %% [markdown]
# # Load Data

# %%
train = pd.read_parquet(
    f"{cfg.dataset_path}/train.parquet",
    columns=["era"] + feature_set + targets
)

valid = pd.read_parquet(
    f"{cfg.dataset_path}/validation.parquet",
    columns=["era"] + feature_set + targets
    
)

print(train.shape)
display(train.head(2))

print(valid.shape)
display(valid.head(2))
# Out:
# (2746270, 45)
#                    era  feature_antistrophic_striate_conscriptionist  \
# id
# n0007b5abb0c3a25  0001                                             2
# n003bba8a98662e4  0001                                             2
#
#                   feature_bicameral_showery_wallaba  \
# id
# n0007b5abb0c3a25                                  2
# n003bba8a98662e4                                  2
#
#                   feature_bridal_fingered_pensioner  \
# id
# n0007b5abb0c3a25                                  2
# n003bba8a98662e4                                  2
#
#                   feature_collectivist_flaxen_gueux  \
# id
# n0007b5abb0c3a25                                  2
# n003bba8a98662e4                                  2
#
#                   feature_concurring_fabled_adapter  \
# id
# n0007b5abb0c3a25                                  2
# n003bba8a98662e4                                  2
#
#                   feature_crosscut_whilom_ataxy  \
# id
# n0007b5abb0c3a25                              0
# n003bba8a98662e4                              1
#
#                   feature_departmental_inimitable_sentencer  \
# id
# n0007b5abb0c3a25                                          1
# n003bba8a98662e4                                          4
#
#                   feature_dialectal_homely_cambodia  \
# id
# n0007b5abb0c3a25                                  2
# n003bba8a98662e4                                  2
#
#                   feature_donnard_groutier_twinkle  ...  \
# id                                                  ...
# n0007b5abb0c3a25                                 2  ...
# n003bba8a98662e4                                 2  ...
#
#                   feature_unanalyzable_excusable_whirlwind  \
# id
# n0007b5abb0c3a25                                         1
# n003bba8a98662e4                                         0
#
#                   feature_unbreakable_constraining_hegelianism  \
# id
# n0007b5abb0c3a25                                             3
# n003bba8a98662e4                                             0
#
#                   feature_unformed_bent_smatch  \
# id
# n0007b5abb0c3a25                             0
# n003bba8a98662e4                             0
#
#                   feature_unministerial_unextenuated_teleostean  \
# id
# n0007b5abb0c3a25                                              2
# n003bba8a98662e4                                              2
#
#                   feature_unmodish_zymogenic_rousing  \
# id
# n0007b5abb0c3a25                                   2
# n003bba8a98662e4                                   2
#
#                   feature_unsystematized_subcardinal_malaysia  \
# id
# n0007b5abb0c3a25                                            3
# n003bba8a98662e4                                            4
#
#                   feature_willful_sere_chronobiology  \
# id
# n0007b5abb0c3a25                                   3
# n003bba8a98662e4                                   4
#
#                   feature_zoological_peristomial_scute  target  \
# id
# n0007b5abb0c3a25                                     2    0.25
# n003bba8a98662e4                                     2    0.25
#
#                   target_agnes_20
# id
# n0007b5abb0c3a25             0.25
# n003bba8a98662e4             0.25
#
# [2 rows x 45 columns]
# (3577827, 45)
#                    era  feature_antistrophic_striate_conscriptionist  \
# id
# n000101811a8a843  0575                                             0
# n001e1318d5072ac  0575                                             1
#
#                   feature_bicameral_showery_wallaba  \
# id
# n000101811a8a843                                  2
# n001e1318d5072ac                                  1
#
#                   feature_bridal_fingered_pensioner  \
# id
# n000101811a8a843                                  1
# n001e1318d5072ac                                  3
#
#                   feature_collectivist_flaxen_gueux  \
# id
# n000101811a8a843                                  2
# n001e1318d5072ac                                  2
#
#                   feature_concurring_fabled_adapter  \
# id
# n000101811a8a843                                  2
# n001e1318d5072ac                                  1
#
#                   feature_crosscut_whilom_ataxy  \
# id
# n000101811a8a843                              1
# n001e1318d5072ac                              3
#
#                   feature_departmental_inimitable_sentencer  \
# id
# n000101811a8a843                                          1
# n001e1318d5072ac                                          3
#
#                   feature_dialectal_homely_cambodia  \
# id
# n000101811a8a843                                  2
# n001e1318d5072ac                                  4
#
#                   feature_donnard_groutier_twinkle  ...  \
# id                                                  ...
# n000101811a8a843                                 2  ...
# n001e1318d5072ac                                 4  ...
#
#                   feature_unanalyzable_excusable_whirlwind  \
# id
# n000101811a8a843                                         3
# n001e1318d5072ac                                         3
#
#                   feature_unbreakable_constraining_hegelianism  \
# id
# n000101811a8a843                                             0
# n001e1318d5072ac                                             2
#
#                   feature_unformed_bent_smatch  \
# id
# n000101811a8a843                             2
# n001e1318d5072ac                             2
#
#                   feature_unministerial_unextenuated_teleostean  \
# id
# n000101811a8a843                                              2
# n001e1318d5072ac                                              3
#
#                   feature_unmodish_zymogenic_rousing  \
# id
# n000101811a8a843                                   1
# n001e1318d5072ac                                   1
#
#                   feature_unsystematized_subcardinal_malaysia  \
# id
# n000101811a8a843                                            3
# n001e1318d5072ac                                            1
#
#                   feature_willful_sere_chronobiology  \
# id
# n000101811a8a843                                   2
# n001e1318d5072ac                                   0
#
#                   feature_zoological_peristomial_scute  target  \
# id
# n000101811a8a843                                     0    0.75
# n001e1318d5072ac                                     1    0.00
#
#                   target_agnes_20
# id
# n000101811a8a843             0.75
# n001e1318d5072ac             0.00
#
# [2 rows x 45 columns]

# %% [markdown]
# # Preprocess

# %%
# 学習データを増やす (train, valid を合体してから分ける)
print(train.shape, valid.shape)

data = pd.concat([train, valid])
display(data.tail())

# era 単位で分ける
all_era = data["era"].unique()
if cfg.valid_ratio:
    n_idx = int(len(all_era) * (1 - cfg.valid_ratio))

    train_era = all_era[:n_idx]
    cond_train = data["era"].isin(train_era)
else:
    cond_train = data["era"].isin(train["era"].values)
print(data.shape)

train, valid = data.loc[cond_train], data.loc[~cond_train]

print(train.shape, valid.shape)
# Out:
# (2746270, 45) (3577827, 45)
#                    era  feature_antistrophic_striate_conscriptionist  \
# id
# nffce425c89dc5da  1153                                             0
# nffd4e7b55827375  1153                                             0
# nffea643830509bf  1153                                             0
# nffea66c53d0aebe  1153                                             1
# nfff2966f1f157af  1153                                             0
#
#                   feature_bicameral_showery_wallaba  \
# id
# nffce425c89dc5da                                  0
# nffd4e7b55827375                                  2
# nffea643830509bf                                  3
# nffea66c53d0aebe                                  2
# nfff2966f1f157af                                  0
#
#                   feature_bridal_fingered_pensioner  \
# id
# nffce425c89dc5da                                  2
# nffd4e7b55827375                                  4
# nffea643830509bf                                  1
# nffea66c53d0aebe                                  0
# nfff2966f1f157af                                  4
#
#                   feature_collectivist_flaxen_gueux  \
# id
# nffce425c89dc5da                                  2
# nffd4e7b55827375                                  2
# nffea643830509bf                                  1
# nffea66c53d0aebe                                  1
# nfff2966f1f157af                                  3
#
#                   feature_concurring_fabled_adapter  \
# id
# nffce425c89dc5da                                  4
# nffd4e7b55827375                                  1
# nffea643830509bf                                  3
# nffea66c53d0aebe                                  2
# nfff2966f1f157af                                  0
#
#                   feature_crosscut_whilom_ataxy  \
# id
# nffce425c89dc5da                              2
# nffd4e7b55827375                              4
# nffea643830509bf                              4
# nffea66c53d0aebe                              2
# nfff2966f1f157af                              4
#
#                   feature_departmental_inimitable_sentencer  \
# id
# nffce425c89dc5da                                          0
# nffd4e7b55827375                                          1
# nffea643830509bf                                          3
# nffea66c53d0aebe                                          1
# nfff2966f1f157af                                          1
#
#                   feature_dialectal_homely_cambodia  \
# id
# nffce425c89dc5da                                  1
# nffd4e7b55827375                                  1
# nffea643830509bf                                  0
# nffea66c53d0aebe                                  3
# nfff2966f1f157af                                  4
#
#                   feature_donnard_groutier_twinkle  ...  \
# id                                                  ...
# nffce425c89dc5da                                 1  ...
# nffd4e7b55827375                                 1  ...
# nffea643830509bf                                 3  ...
# nffea66c53d0aebe                                 1  ...
# nfff2966f1f157af                                 4  ...
#
#                   feature_unanalyzable_excusable_whirlwind  \
# id
# nffce425c89dc5da                                         0
# nffd4e7b55827375                                         4
# nffea643830509bf                                         3
# nffea66c53d0aebe                                         1
# nfff2966f1f157af                                         1
#
#                   feature_unbreakable_constraining_hegelianism  \
# id
# nffce425c89dc5da                                             4
# nffd4e7b55827375                                             2
# nffea643830509bf                                             3
# nffea66c53d0aebe                                             1
# nfff2966f1f157af                                             0
#
#                   feature_unformed_bent_smatch  \
# id
# nffce425c89dc5da                             2
# nffd4e7b55827375                             4
# nffea643830509bf                             3
# nffea66c53d0aebe                             2
# nfff2966f1f157af                             0
#
#                   feature_unministerial_unextenuated_teleostean  \
# id
# nffce425c89dc5da                                              4
# nffd4e7b55827375                                              2
# nffea643830509bf                                              3
# nffea66c53d0aebe                                              2
# nfff2966f1f157af                                              4
#
#                   feature_unmodish_zymogenic_rousing  \
# id
# nffce425c89dc5da                                   1
# nffd4e7b55827375                                   2
# nffea643830509bf                                   0
# nffea66c53d0aebe                                   3
# nfff2966f1f157af                                   0
#
#                   feature_unsystematized_subcardinal_malaysia  \
# id
# nffce425c89dc5da                                            3
# nffd4e7b55827375                                            4
# nffea643830509bf                                            2
# nffea66c53d0aebe                                            1
# nfff2966f1f157af                                            2
#
#                   feature_willful_sere_chronobiology  \
# id
# nffce425c89dc5da                                   1
# nffd4e7b55827375                                   0
# nffea643830509bf                                   2
# nffea66c53d0aebe                                   1
# nfff2966f1f157af                                   1
#
#                   feature_zoological_peristomial_scute  target  \
# id
# nffce425c89dc5da                                     0     NaN
# nffd4e7b55827375                                     3     NaN
# nffea643830509bf                                     2     NaN
# nffea66c53d0aebe                                     3     NaN
# nfff2966f1f157af                                     4     NaN
#
#                   target_agnes_20
# id
# nffce425c89dc5da              NaN
# nffd4e7b55827375              NaN
# nffea643830509bf              NaN
# nffea66c53d0aebe              NaN
# nfff2966f1f157af              NaN
#
# [5 rows x 45 columns]
# (6324097, 45)
# (2746270, 45) (3577827, 45)

# %%
train["era_int"] = train["era"].astype(int)
# Out:
# /tmp/ipykernel_104792/1731592198.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train["era_int"] = train["era"].astype(int)

# %% [markdown]
# # Training

# %%
features = feature_set

# %%
models = []

for target in targets:
    print("=" * 64)
    print("target: ", target)
    for i in range(4):
        cond_train = (train["era_int"] % 4 == i) & (~train[target].isnull())
        cond_valid = ~valid[target].isnull()
        tmp_train = train.loc[cond_train]
        tmp_valid = valid.loc[cond_valid]

        model = src_model.LightGBMModel(
            model_params=cfg.model_params,
        )
        model.train(
            tmp_train[features],
            tmp_train[target],
            eval_set=(tmp_valid[features], tmp_valid[target]),
            early_stopping_rounds=10
        )
        models.append(model)
        model.save_model(os.path.join(cfg.exp, f"model_{i}_{target}.pkl"))

with open(os.path.join(cfg.exp, "feature.pkl"), "wb") as f:
     pickle.dump(features, f)
# Out:
# ================================================================
# target:  target
# /home/kouya-takahashi/.local/lib/python3.9/site-packages/lightgbm/engine.py:204: UserWarning: Found `n_estimators` in params. Will use it instead of argument
#   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# [LightGBM] [Warning] Provided parameters constrain tree depth (max_depth=5) without explicitly setting 'num_leaves'. This can lead to underfitting. To resolve this warning, pass 'num_leaves' (<=32) in params. Alternatively, pass (max_depth=-1) and just use 'num_leaves' to constrain model complexity.
# [LightGBM] [Warning] Provided parameters constrain tree depth (max_depth=5) without explicitly setting 'num_leaves'. This can lead to underfitting. To resolve this warning, pass 'num_leaves' (<=32) in params. Alternatively, pass (max_depth=-1) and just use 'num_leaves' to constrain model complexity.
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.003679 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 210
# [LightGBM] [Info] Number of data points in the train set: 684735, number of used features: 42
# [LightGBM] [Warning] Provided parameters constrain tree depth (max_depth=5) without explicitly setting 'num_leaves'. This can lead to underfitting. To resolve this warning, pass 'num_leaves' (<=32) in params. Alternatively, pass (max_depth=-1) and just use 'num_leaves' to constrain model complexity.
# [LightGBM] [Info] Start training from score 0.500014
# Training until validation scores don't improve for 10 rounds
# Early stopping, best iteration is:
# [324]	valid_0's l2: 0.0498241
# /home/kouya-takahashi/.local/lib/python3.9/site-packages/lightgbm/engine.py:204: UserWarning: Found `n_estimators` in params. Will use it instead of argument
#   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# [LightGBM] [Warning] Provided parameters constrain tree depth (max_depth=5) without explicitly setting 'num_leaves'. This can lead to underfitting. To resolve this warning, pass 'num_leaves' (<=32) in params. Alternatively, pass (max_depth=-1) and just use 'num_leaves' to constrain model complexity.
# [LightGBM] [Warning] Provided parameters constrain tree depth (max_depth=5) without explicitly setting 'num_leaves'. This can lead to underfitting. To resolve this warning, pass 'num_leaves' (<=32) in params. Alternatively, pass (max_depth=-1) and just use 'num_leaves' to constrain model complexity.
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.001555 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 210
# [LightGBM] [Info] Number of data points in the train set: 688184, number of used features: 42
# [LightGBM] [Warning] Provided parameters constrain tree depth (max_depth=5) without explicitly setting 'num_leaves'. This can lead to underfitting. To resolve this warning, pass 'num_leaves' (<=32) in params. Alternatively, pass (max_depth=-1) and just use 'num_leaves' to constrain model complexity.
# [LightGBM] [Info] Start training from score 0.500008
# Training until validation scores don't improve for 10 rounds
# Early stopping, best iteration is:
# [324]	valid_0's l2: 0.0498244
# /home/kouya-takahashi/.local/lib/python3.9/site-packages/lightgbm/engine.py:204: UserWarning: Found `n_estimators` in params. Will use it instead of argument
#   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# [LightGBM] [Warning] Provided parameters constrain tree depth (max_depth=5) without explicitly setting 'num_leaves'. This can lead to underfitting. To resolve this warning, pass 'num_leaves' (<=32) in params. Alternatively, pass (max_depth=-1) and just use 'num_leaves' to constrain model complexity.
# [LightGBM] [Warning] Provided parameters constrain tree depth (max_depth=5) without explicitly setting 'num_leaves'. This can lead to underfitting. To resolve this warning, pass 'num_leaves' (<=32) in params. Alternatively, pass (max_depth=-1) and just use 'num_leaves' to constrain model complexity.
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.001536 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 210
# [LightGBM] [Info] Number of data points in the train set: 689317, number of used features: 42
# [LightGBM] [Warning] Provided parameters constrain tree depth (max_depth=5) without explicitly setting 'num_leaves'. This can lead to underfitting. To resolve this warning, pass 'num_leaves' (<=32) in params. Alternatively, pass (max_depth=-1) and just use 'num_leaves' to constrain model complexity.
# [LightGBM] [Info] Start training from score 0.500040
# Training until validation scores don't improve for 10 rounds
# Early stopping, best iteration is:
# [324]	valid_0's l2: 0.0498243
# /home/kouya-takahashi/.local/lib/python3.9/site-packages/lightgbm/engine.py:204: UserWarning: Found `n_estimators` in params. Will use it instead of argument
#   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# [LightGBM] [Warning] Provided parameters constrain tree depth (max_depth=5) without explicitly setting 'num_leaves'. This can lead to underfitting. To resolve this warning, pass 'num_leaves' (<=32) in params. Alternatively, pass (max_depth=-1) and just use 'num_leaves' to constrain model complexity.
# [LightGBM] [Warning] Provided parameters constrain tree depth (max_depth=5) without explicitly setting 'num_leaves'. This can lead to underfitting. To resolve this warning, pass 'num_leaves' (<=32) in params. Alternatively, pass (max_depth=-1) and just use 'num_leaves' to constrain model complexity.
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.001610 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 210
# [LightGBM] [Info] Number of data points in the train set: 684034, number of used features: 42
# [LightGBM] [Warning] Provided parameters constrain tree depth (max_depth=5) without explicitly setting 'num_leaves'. This can lead to underfitting. To resolve this warning, pass 'num_leaves' (<=32) in params. Alternatively, pass (max_depth=-1) and just use 'num_leaves' to constrain model complexity.
# [LightGBM] [Info] Start training from score 0.500045
# Training until validation scores don't improve for 10 rounds
# Early stopping, best iteration is:
# [351]	valid_0's l2: 0.0498237
# ================================================================
# target:  target_agnes_20
# /home/kouya-takahashi/.local/lib/python3.9/site-packages/lightgbm/engine.py:204: UserWarning: Found `n_estimators` in params. Will use it instead of argument
#   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# [LightGBM] [Warning] Provided parameters constrain tree depth (max_depth=5) without explicitly setting 'num_leaves'. This can lead to underfitting. To resolve this warning, pass 'num_leaves' (<=32) in params. Alternatively, pass (max_depth=-1) and just use 'num_leaves' to constrain model complexity.
# [LightGBM] [Warning] Provided parameters constrain tree depth (max_depth=5) without explicitly setting 'num_leaves'. This can lead to underfitting. To resolve this warning, pass 'num_leaves' (<=32) in params. Alternatively, pass (max_depth=-1) and just use 'num_leaves' to constrain model complexity.
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.003924 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 210
# [LightGBM] [Info] Number of data points in the train set: 684735, number of used features: 42
# [LightGBM] [Warning] Provided parameters constrain tree depth (max_depth=5) without explicitly setting 'num_leaves'. This can lead to underfitting. To resolve this warning, pass 'num_leaves' (<=32) in params. Alternatively, pass (max_depth=-1) and just use 'num_leaves' to constrain model complexity.
# [LightGBM] [Info] Start training from score 0.500072
# Training until validation scores don't improve for 10 rounds
# Early stopping, best iteration is:
# [291]	valid_0's l2: 0.0496433
# /home/kouya-takahashi/.local/lib/python3.9/site-packages/lightgbm/engine.py:204: UserWarning: Found `n_estimators` in params. Will use it instead of argument
#   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# [LightGBM] [Warning] Provided parameters constrain tree depth (max_depth=5) without explicitly setting 'num_leaves'. This can lead to underfitting. To resolve this warning, pass 'num_leaves' (<=32) in params. Alternatively, pass (max_depth=-1) and just use 'num_leaves' to constrain model complexity.
# [LightGBM] [Warning] Provided parameters constrain tree depth (max_depth=5) without explicitly setting 'num_leaves'. This can lead to underfitting. To resolve this warning, pass 'num_leaves' (<=32) in params. Alternatively, pass (max_depth=-1) and just use 'num_leaves' to constrain model complexity.
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.001654 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 210
# [LightGBM] [Info] Number of data points in the train set: 688184, number of used features: 42
# [LightGBM] [Warning] Provided parameters constrain tree depth (max_depth=5) without explicitly setting 'num_leaves'. This can lead to underfitting. To resolve this warning, pass 'num_leaves' (<=32) in params. Alternatively, pass (max_depth=-1) and just use 'num_leaves' to constrain model complexity.
# [LightGBM] [Info] Start training from score 0.500126
# Training until validation scores don't improve for 10 rounds
# Early stopping, best iteration is:
# [327]	valid_0's l2: 0.0496408
# /home/kouya-takahashi/.local/lib/python3.9/site-packages/lightgbm/engine.py:204: UserWarning: Found `n_estimators` in params. Will use it instead of argument
#   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# [LightGBM] [Warning] Provided parameters constrain tree depth (max_depth=5) without explicitly setting 'num_leaves'. This can lead to underfitting. To resolve this warning, pass 'num_leaves' (<=32) in params. Alternatively, pass (max_depth=-1) and just use 'num_leaves' to constrain model complexity.
# [LightGBM] [Warning] Provided parameters constrain tree depth (max_depth=5) without explicitly setting 'num_leaves'. This can lead to underfitting. To resolve this warning, pass 'num_leaves' (<=32) in params. Alternatively, pass (max_depth=-1) and just use 'num_leaves' to constrain model complexity.
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.001894 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 210
# [LightGBM] [Info] Number of data points in the train set: 689317, number of used features: 42
# [LightGBM] [Warning] Provided parameters constrain tree depth (max_depth=5) without explicitly setting 'num_leaves'. This can lead to underfitting. To resolve this warning, pass 'num_leaves' (<=32) in params. Alternatively, pass (max_depth=-1) and just use 'num_leaves' to constrain model complexity.
# [LightGBM] [Info] Start training from score 0.500100
# Training until validation scores don't improve for 10 rounds
# Early stopping, best iteration is:
# [528]	valid_0's l2: 0.0496333
# /home/kouya-takahashi/.local/lib/python3.9/site-packages/lightgbm/engine.py:204: UserWarning: Found `n_estimators` in params. Will use it instead of argument
#   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# [LightGBM] [Warning] Provided parameters constrain tree depth (max_depth=5) without explicitly setting 'num_leaves'. This can lead to underfitting. To resolve this warning, pass 'num_leaves' (<=32) in params. Alternatively, pass (max_depth=-1) and just use 'num_leaves' to constrain model complexity.
# [LightGBM] [Warning] Provided parameters constrain tree depth (max_depth=5) without explicitly setting 'num_leaves'. This can lead to underfitting. To resolve this warning, pass 'num_leaves' (<=32) in params. Alternatively, pass (max_depth=-1) and just use 'num_leaves' to constrain model complexity.
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.001935 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 210
# [LightGBM] [Info] Number of data points in the train set: 684034, number of used features: 42
# [LightGBM] [Warning] Provided parameters constrain tree depth (max_depth=5) without explicitly setting 'num_leaves'. This can lead to underfitting. To resolve this warning, pass 'num_leaves' (<=32) in params. Alternatively, pass (max_depth=-1) and just use 'num_leaves' to constrain model complexity.
# [LightGBM] [Info] Start training from score 0.500047
# Training until validation scores don't improve for 10 rounds
# Early stopping, best iteration is:
# [495]	valid_0's l2: 0.0496361

# %%
print(len(models))

for model in models:
    model.visualize_learning_curve()
    model.visualize_feature_importance()
    break
# Out:
# 8

# %% [markdown]
# # Validation

# %%
preds = np.zeros(len(valid))

for model in models:
    preds += model.predict(valid[features]) / len(models)

valid["pred"] = preds
# src_validation.caluculate_metrics(cfg.dataset_path, valid)
# Out:
# /tmp/ipykernel_104792/2461060283.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   valid["pred"] = preds

# %%
# valid["prediction"] = valid["pred"]

# valid.to_csv(f"{cfg.exp}/valid_prediction.csv")

# %%
napi.download_dataset(f"{cfg.data_version}/live.parquet")
live_features = pd.read_parquet(f"{cfg.data_version}/live.parquet", columns=features)

def predict(live_features):
    preds = np.zeros(len(live_features))
    
    for model in models:
        preds += model.predict(live_features[features]) / len(models)
    submission = pd.Series(preds, index=live_features.index)
    return submission.to_frame("prediction")

p = cloudpickle.dumps(predict)
with open(f"{cfg.exp}/submission.pkl", "wb") as f:
    f.write(p)
# Out:
# 2025-02-20 23:02:41,592 INFO numerapi.utils: target file already exists
# 2025-02-20 23:02:41,594 INFO numerapi.utils: starting download
# v5.0/live.parquet: 15.7MB [00:04, 3.22MB/s]
