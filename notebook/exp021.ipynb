# %%
# %load_ext autoreload
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
# %autoreload 2

import os
import sys
import json
import gc
import pickle 
import wandb

from numerapi import NumerAPI
from numerai_tools.scoring import numerai_corr, correlation_contribution

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.metrics import mean_squared_error

import lightgbm as lgb

sys.path.append("../")
from src.model import LightGBMModel
from src.validation import caluculate_metrics

# %% [markdown]
# # Config

# %%
class cfg:
    project = "numerai_tournament"
    exp = "exp021"
    dataset_path = "../dataset/v5.0"
    feature_set = "small"
    valid_ratio = 0.2
    description = "target_agnes_60 追加"
    
    model_params = {
        "objective": "regression",
        "metric": "l2",
        "n_estimators": 2000,
        "max_depth": 5,
        "learning_rate": 0.01,
        "feature_fraction": 0.1,
        "seed": 42,
    }

has_init_wandb = False
if not has_init_wandb:
    wandb.init(project=cfg.project, name=cfg.exp)
    wandb.log({
        "description": cfg.description,
        "feature_set": cfg.feature_set,
    })
    has_init_wandb = True

# %%
# 実験用フォルダ作成    
os.makedirs(cfg.exp, exist_ok=True)

# 辞書形式に変換して保存 (推論時に使用する)
cfg_dict = {attr: getattr(cfg, attr) for attr in dir(cfg) if not attr.startswith("__") and not callable(getattr(cfg, attr))}
config_file = os.path.join(cfg.exp, "training_config.json")
with open(config_file, "w") as f:
    json.dump(cfg_dict, f, indent=4)

with open(f"{cfg.dataset_path}/features.json", "r") as f:
    feature_metadata = json.load(f)

# print(feature_metadata.keys())
feature_sets = feature_metadata["feature_sets"]
# print(feature_sets.keys())
feature_set = feature_sets[cfg.feature_set][:80]
print(f"feature col length: {len(feature_set)}")


targets = feature_metadata["targets"]
targets = ["target", "target_agnes_20", "target_agnes_60"]
# Out:
# feature col length: 42

# %% [markdown]
# # Load Data

# %%
train = pd.read_parquet(
    f"{cfg.dataset_path}/train.parquet",
    columns=["era"] + feature_set + targets
)

valid = pd.read_parquet(
    f"{cfg.dataset_path}/validation.parquet",
    columns=["era"] + feature_set + targets
    
)

print(train.shape)
display(train.head(2))

print(valid.shape)
display(valid.head(2))
# Out:
# (2746270, 46)
#                    era  feature_antistrophic_striate_conscriptionist  \
# id
# n0007b5abb0c3a25  0001                                             2
# n003bba8a98662e4  0001                                             2
#
#                   feature_bicameral_showery_wallaba  \
# id
# n0007b5abb0c3a25                                  2
# n003bba8a98662e4                                  2
#
#                   feature_bridal_fingered_pensioner  \
# id
# n0007b5abb0c3a25                                  2
# n003bba8a98662e4                                  2
#
#                   feature_collectivist_flaxen_gueux  \
# id
# n0007b5abb0c3a25                                  2
# n003bba8a98662e4                                  2
#
#                   feature_concurring_fabled_adapter  \
# id
# n0007b5abb0c3a25                                  2
# n003bba8a98662e4                                  2
#
#                   feature_crosscut_whilom_ataxy  \
# id
# n0007b5abb0c3a25                              0
# n003bba8a98662e4                              1
#
#                   feature_departmental_inimitable_sentencer  \
# id
# n0007b5abb0c3a25                                          1
# n003bba8a98662e4                                          4
#
#                   feature_dialectal_homely_cambodia  \
# id
# n0007b5abb0c3a25                                  2
# n003bba8a98662e4                                  2
#
#                   feature_donnard_groutier_twinkle  ...  \
# id                                                  ...
# n0007b5abb0c3a25                                 2  ...
# n003bba8a98662e4                                 2  ...
#
#                   feature_unbreakable_constraining_hegelianism  \
# id
# n0007b5abb0c3a25                                             3
# n003bba8a98662e4                                             0
#
#                   feature_unformed_bent_smatch  \
# id
# n0007b5abb0c3a25                             0
# n003bba8a98662e4                             0
#
#                   feature_unministerial_unextenuated_teleostean  \
# id
# n0007b5abb0c3a25                                              2
# n003bba8a98662e4                                              2
#
#                   feature_unmodish_zymogenic_rousing  \
# id
# n0007b5abb0c3a25                                   2
# n003bba8a98662e4                                   2
#
#                   feature_unsystematized_subcardinal_malaysia  \
# id
# n0007b5abb0c3a25                                            3
# n003bba8a98662e4                                            4
#
#                   feature_willful_sere_chronobiology  \
# id
# n0007b5abb0c3a25                                   3
# n003bba8a98662e4                                   4
#
#                   feature_zoological_peristomial_scute  target  \
# id
# n0007b5abb0c3a25                                     2    0.25
# n003bba8a98662e4                                     2    0.25
#
#                   target_agnes_20  target_agnes_60
# id
# n0007b5abb0c3a25             0.25             0.00
# n003bba8a98662e4             0.25             0.25
#
# [2 rows x 46 columns]
# (3590190, 46)
#                    era  feature_antistrophic_striate_conscriptionist  \
# id
# n000101811a8a843  0575                                             0
# n001e1318d5072ac  0575                                             1
#
#                   feature_bicameral_showery_wallaba  \
# id
# n000101811a8a843                                  2
# n001e1318d5072ac                                  1
#
#                   feature_bridal_fingered_pensioner  \
# id
# n000101811a8a843                                  1
# n001e1318d5072ac                                  3
#
#                   feature_collectivist_flaxen_gueux  \
# id
# n000101811a8a843                                  2
# n001e1318d5072ac                                  2
#
#                   feature_concurring_fabled_adapter  \
# id
# n000101811a8a843                                  2
# n001e1318d5072ac                                  1
#
#                   feature_crosscut_whilom_ataxy  \
# id
# n000101811a8a843                              1
# n001e1318d5072ac                              3
#
#                   feature_departmental_inimitable_sentencer  \
# id
# n000101811a8a843                                          1
# n001e1318d5072ac                                          3
#
#                   feature_dialectal_homely_cambodia  \
# id
# n000101811a8a843                                  2
# n001e1318d5072ac                                  4
#
#                   feature_donnard_groutier_twinkle  ...  \
# id                                                  ...
# n000101811a8a843                                 2  ...
# n001e1318d5072ac                                 4  ...
#
#                   feature_unbreakable_constraining_hegelianism  \
# id
# n000101811a8a843                                             0
# n001e1318d5072ac                                             2
#
#                   feature_unformed_bent_smatch  \
# id
# n000101811a8a843                             2
# n001e1318d5072ac                             2
#
#                   feature_unministerial_unextenuated_teleostean  \
# id
# n000101811a8a843                                              2
# n001e1318d5072ac                                              3
#
#                   feature_unmodish_zymogenic_rousing  \
# id
# n000101811a8a843                                   1
# n001e1318d5072ac                                   1
#
#                   feature_unsystematized_subcardinal_malaysia  \
# id
# n000101811a8a843                                            3
# n001e1318d5072ac                                            1
#
#                   feature_willful_sere_chronobiology  \
# id
# n000101811a8a843                                   2
# n001e1318d5072ac                                   0
#
#                   feature_zoological_peristomial_scute  target  \
# id
# n000101811a8a843                                     0    0.75
# n001e1318d5072ac                                     1    0.00
#
#                   target_agnes_20  target_agnes_60
# id
# n000101811a8a843             0.75             0.50
# n001e1318d5072ac             0.00             0.25
#
# [2 rows x 46 columns]

# %% [markdown]
# # Preprocess

# %%
# 学習データを増やす (train, valid を合体してから分ける)
print(train.shape, valid.shape)

data = pd.concat([train, valid])
display(data.tail())

# era 単位で分ける
all_era = data["era"].unique()
n_idx = int(len(all_era) * (1 - cfg.valid_ratio))
print(data.shape)
print(n_idx)

train_era = all_era[:n_idx]
cond_train = data["era"].isin(train_era)
train, valid = data.loc[cond_train], data.loc[~cond_train]

print(train.shape, valid.shape)
# Out:
# (2746270, 46) (3590190, 46)
#                    era  feature_antistrophic_striate_conscriptionist  \
# id
# nffddb5d88eac837  1155                                             1
# nffe2864d87608a4  1155                                             4
# nffe68d1b4270d67  1155                                             2
# nffeedfcd8ee0a13  1155                                             2
# nfff368efc94f367  1155                                             4
#
#                   feature_bicameral_showery_wallaba  \
# id
# nffddb5d88eac837                                  2
# nffe2864d87608a4                                  4
# nffe68d1b4270d67                                  0
# nffeedfcd8ee0a13                                  1
# nfff368efc94f367                                  2
#
#                   feature_bridal_fingered_pensioner  \
# id
# nffddb5d88eac837                                  4
# nffe2864d87608a4                                  2
# nffe68d1b4270d67                                  1
# nffeedfcd8ee0a13                                  1
# nfff368efc94f367                                  3
#
#                   feature_collectivist_flaxen_gueux  \
# id
# nffddb5d88eac837                                  1
# nffe2864d87608a4                                  4
# nffe68d1b4270d67                                  0
# nffeedfcd8ee0a13                                  2
# nfff368efc94f367                                  3
#
#                   feature_concurring_fabled_adapter  \
# id
# nffddb5d88eac837                                  1
# nffe2864d87608a4                                  4
# nffe68d1b4270d67                                  3
# nffeedfcd8ee0a13                                  2
# nfff368efc94f367                                  3
#
#                   feature_crosscut_whilom_ataxy  \
# id
# nffddb5d88eac837                              4
# nffe2864d87608a4                              3
# nffe68d1b4270d67                              0
# nffeedfcd8ee0a13                              4
# nfff368efc94f367                              3
#
#                   feature_departmental_inimitable_sentencer  \
# id
# nffddb5d88eac837                                          3
# nffe2864d87608a4                                          1
# nffe68d1b4270d67                                          2
# nffeedfcd8ee0a13                                          2
# nfff368efc94f367                                          4
#
#                   feature_dialectal_homely_cambodia  \
# id
# nffddb5d88eac837                                  2
# nffe2864d87608a4                                  1
# nffe68d1b4270d67                                  3
# nffeedfcd8ee0a13                                  2
# nfff368efc94f367                                  4
#
#                   feature_donnard_groutier_twinkle  ...  \
# id                                                  ...
# nffddb5d88eac837                                 3  ...
# nffe2864d87608a4                                 1  ...
# nffe68d1b4270d67                                 0  ...
# nffeedfcd8ee0a13                                 2  ...
# nfff368efc94f367                                 0  ...
#
#                   feature_unbreakable_constraining_hegelianism  \
# id
# nffddb5d88eac837                                             2
# nffe2864d87608a4                                             4
# nffe68d1b4270d67                                             0
# nffeedfcd8ee0a13                                             0
# nfff368efc94f367                                             2
#
#                   feature_unformed_bent_smatch  \
# id
# nffddb5d88eac837                             3
# nffe2864d87608a4                             0
# nffe68d1b4270d67                             3
# nffeedfcd8ee0a13                             4
# nfff368efc94f367                             4
#
#                   feature_unministerial_unextenuated_teleostean  \
# id
# nffddb5d88eac837                                              0
# nffe2864d87608a4                                              2
# nffe68d1b4270d67                                              2
# nffeedfcd8ee0a13                                              2
# nfff368efc94f367                                              1
#
#                   feature_unmodish_zymogenic_rousing  \
# id
# nffddb5d88eac837                                   1
# nffe2864d87608a4                                   2
# nffe68d1b4270d67                                   3
# nffeedfcd8ee0a13                                   2
# nfff368efc94f367                                   0
#
#                   feature_unsystematized_subcardinal_malaysia  \
# id
# nffddb5d88eac837                                            3
# nffe2864d87608a4                                            3
# nffe68d1b4270d67                                            4
# nffeedfcd8ee0a13                                            4
# nfff368efc94f367                                            3
#
#                   feature_willful_sere_chronobiology  \
# id
# nffddb5d88eac837                                   1
# nffe2864d87608a4                                   3
# nffe68d1b4270d67                                   4
# nffeedfcd8ee0a13                                   0
# nfff368efc94f367                                   3
#
#                   feature_zoological_peristomial_scute  target  \
# id
# nffddb5d88eac837                                     1     NaN
# nffe2864d87608a4                                     0     NaN
# nffe68d1b4270d67                                     4     NaN
# nffeedfcd8ee0a13                                     2     NaN
# nfff368efc94f367                                     2     NaN
#
#                   target_agnes_20  target_agnes_60
# id
# nffddb5d88eac837              NaN              NaN
# nffe2864d87608a4              NaN              NaN
# nffe68d1b4270d67              NaN              NaN
# nffeedfcd8ee0a13              NaN              NaN
# nfff368efc94f367              NaN              NaN
#
# [5 rows x 46 columns]
# (6336460, 46)
# 924
# (4830256, 46) (1506204, 46)

# %%
train["era_int"] = train["era"].astype(int)
# Out:
# /tmp/ipykernel_148404/1731592198.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train["era_int"] = train["era"].astype(int)

# %% [markdown]
# # Training

# %%
features = feature_set

# %%
models = []

for target in targets:
    print("=" * 64)
    print("target: ", target)
    for i in range(4):
        # 学習データを取り出す間隔を設定
        # target または 末尾に 20 がついてるもの: 4
        # 末尾に 60 がついてるもの: 12
        if target == "target" or target[-2:] == "20":
            blank = 4
        elif target[-2:] == "60":
            blank = 12
        else:
            raise ValueError(f"Unknown target: {target}")
        cond_train = (train["era_int"] % 4 == i) & (~train[target].isnull())
        cond_valid = ~valid[target].isnull()
        tmp_train = train.loc[cond_train]
        tmp_valid = valid.loc[cond_valid]

        model = LightGBMModel(
            model_params=cfg.model_params,
        )
        model.train(
            tmp_train[features],
            tmp_train[target],
            eval_set=(tmp_valid[features], tmp_valid[target]),
            early_stopping_rounds=10
        )
        models.append(model)
        model.save_model(os.path.join(cfg.exp, f"model_{i}_{target}.pkl"))

with open(os.path.join(cfg.exp, "feature.pkl"), "wb") as f:
     pickle.dump(features, f)
# Out:
# ================================================================
# target:  target
# /home/kouya-takahashi/.local/lib/python3.9/site-packages/lightgbm/engine.py:204: UserWarning: Found `n_estimators` in params. Will use it instead of argument
#   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# [LightGBM] [Warning] Provided parameters constrain tree depth (max_depth=5) without explicitly setting 'num_leaves'. This can lead to underfitting. To resolve this warning, pass 'num_leaves' (<=32) in params. Alternatively, pass (max_depth=-1) and just use 'num_leaves' to constrain model complexity.
# [LightGBM] [Warning] Provided parameters constrain tree depth (max_depth=5) without explicitly setting 'num_leaves'. This can lead to underfitting. To resolve this warning, pass 'num_leaves' (<=32) in params. Alternatively, pass (max_depth=-1) and just use 'num_leaves' to constrain model complexity.
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.004750 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 210
# [LightGBM] [Info] Number of data points in the train set: 1208388, number of used features: 42
# [LightGBM] [Warning] Provided parameters constrain tree depth (max_depth=5) without explicitly setting 'num_leaves'. This can lead to underfitting. To resolve this warning, pass 'num_leaves' (<=32) in params. Alternatively, pass (max_depth=-1) and just use 'num_leaves' to constrain model complexity.
# [LightGBM] [Info] Start training from score 0.500032
# Training until validation scores don't improve for 10 rounds
# Early stopping, best iteration is:
# [518]	valid_0's l2: 0.0498296
# /home/kouya-takahashi/.local/lib/python3.9/site-packages/lightgbm/engine.py:204: UserWarning: Found `n_estimators` in params. Will use it instead of argument
#   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# [LightGBM] [Warning] Provided parameters constrain tree depth (max_depth=5) without explicitly setting 'num_leaves'. This can lead to underfitting. To resolve this warning, pass 'num_leaves' (<=32) in params. Alternatively, pass (max_depth=-1) and just use 'num_leaves' to constrain model complexity.
# [LightGBM] [Warning] Provided parameters constrain tree depth (max_depth=5) without explicitly setting 'num_leaves'. This can lead to underfitting. To resolve this warning, pass 'num_leaves' (<=32) in params. Alternatively, pass (max_depth=-1) and just use 'num_leaves' to constrain model complexity.
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.003257 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 210
# [LightGBM] [Info] Number of data points in the train set: 1205900, number of used features: 42
# [LightGBM] [Warning] Provided parameters constrain tree depth (max_depth=5) without explicitly setting 'num_leaves'. This can lead to underfitting. To resolve this warning, pass 'num_leaves' (<=32) in params. Alternatively, pass (max_depth=-1) and just use 'num_leaves' to constrain model complexity.
# [LightGBM] [Info] Start training from score 0.500020
# Training until validation scores don't improve for 10 rounds
# Early stopping, best iteration is:
# [527]	valid_0's l2: 0.0498307
# /home/kouya-takahashi/.local/lib/python3.9/site-packages/lightgbm/engine.py:204: UserWarning: Found `n_estimators` in params. Will use it instead of argument
#   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# [LightGBM] [Warning] Provided parameters constrain tree depth (max_depth=5) without explicitly setting 'num_leaves'. This can lead to underfitting. To resolve this warning, pass 'num_leaves' (<=32) in params. Alternatively, pass (max_depth=-1) and just use 'num_leaves' to constrain model complexity.
# [LightGBM] [Warning] Provided parameters constrain tree depth (max_depth=5) without explicitly setting 'num_leaves'. This can lead to underfitting. To resolve this warning, pass 'num_leaves' (<=32) in params. Alternatively, pass (max_depth=-1) and just use 'num_leaves' to constrain model complexity.
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.003340 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 210
# [LightGBM] [Info] Number of data points in the train set: 1207776, number of used features: 42
# [LightGBM] [Warning] Provided parameters constrain tree depth (max_depth=5) without explicitly setting 'num_leaves'. This can lead to underfitting. To resolve this warning, pass 'num_leaves' (<=32) in params. Alternatively, pass (max_depth=-1) and just use 'num_leaves' to constrain model complexity.
# [LightGBM] [Info] Start training from score 0.500018
# Training until validation scores don't improve for 10 rounds
# Early stopping, best iteration is:
# [494]	valid_0's l2: 0.0498308
# /home/kouya-takahashi/.local/lib/python3.9/site-packages/lightgbm/engine.py:204: UserWarning: Found `n_estimators` in params. Will use it instead of argument
#   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# [LightGBM] [Warning] Provided parameters constrain tree depth (max_depth=5) without explicitly setting 'num_leaves'. This can lead to underfitting. To resolve this warning, pass 'num_leaves' (<=32) in params. Alternatively, pass (max_depth=-1) and just use 'num_leaves' to constrain model complexity.
# [LightGBM] [Warning] Provided parameters constrain tree depth (max_depth=5) without explicitly setting 'num_leaves'. This can lead to underfitting. To resolve this warning, pass 'num_leaves' (<=32) in params. Alternatively, pass (max_depth=-1) and just use 'num_leaves' to constrain model complexity.
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.002613 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 210
# [LightGBM] [Info] Number of data points in the train set: 1208192, number of used features: 42
# [LightGBM] [Warning] Provided parameters constrain tree depth (max_depth=5) without explicitly setting 'num_leaves'. This can lead to underfitting. To resolve this warning, pass 'num_leaves' (<=32) in params. Alternatively, pass (max_depth=-1) and just use 'num_leaves' to constrain model complexity.
# [LightGBM] [Info] Start training from score 0.500024
# Training until validation scores don't improve for 10 rounds
# Early stopping, best iteration is:
# [495]	valid_0's l2: 0.0498308
# ================================================================
# target:  target_agnes_20
# /home/kouya-takahashi/.local/lib/python3.9/site-packages/lightgbm/engine.py:204: UserWarning: Found `n_estimators` in params. Will use it instead of argument
#   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# [LightGBM] [Warning] Provided parameters constrain tree depth (max_depth=5) without explicitly setting 'num_leaves'. This can lead to underfitting. To resolve this warning, pass 'num_leaves' (<=32) in params. Alternatively, pass (max_depth=-1) and just use 'num_leaves' to constrain model complexity.
# [LightGBM] [Warning] Provided parameters constrain tree depth (max_depth=5) without explicitly setting 'num_leaves'. This can lead to underfitting. To resolve this warning, pass 'num_leaves' (<=32) in params. Alternatively, pass (max_depth=-1) and just use 'num_leaves' to constrain model complexity.
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.006828 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 210
# [LightGBM] [Info] Number of data points in the train set: 1208388, number of used features: 42
# [LightGBM] [Warning] Provided parameters constrain tree depth (max_depth=5) without explicitly setting 'num_leaves'. This can lead to underfitting. To resolve this warning, pass 'num_leaves' (<=32) in params. Alternatively, pass (max_depth=-1) and just use 'num_leaves' to constrain model complexity.
# [LightGBM] [Info] Start training from score 0.500054
# Training until validation scores don't improve for 10 rounds
# Early stopping, best iteration is:
# [538]	valid_0's l2: 0.0496492
# /home/kouya-takahashi/.local/lib/python3.9/site-packages/lightgbm/engine.py:204: UserWarning: Found `n_estimators` in params. Will use it instead of argument
#   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# [LightGBM] [Warning] Provided parameters constrain tree depth (max_depth=5) without explicitly setting 'num_leaves'. This can lead to underfitting. To resolve this warning, pass 'num_leaves' (<=32) in params. Alternatively, pass (max_depth=-1) and just use 'num_leaves' to constrain model complexity.
# [LightGBM] [Warning] Provided parameters constrain tree depth (max_depth=5) without explicitly setting 'num_leaves'. This can lead to underfitting. To resolve this warning, pass 'num_leaves' (<=32) in params. Alternatively, pass (max_depth=-1) and just use 'num_leaves' to constrain model complexity.
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.002632 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 210
# [LightGBM] [Info] Number of data points in the train set: 1205900, number of used features: 42
# [LightGBM] [Warning] Provided parameters constrain tree depth (max_depth=5) without explicitly setting 'num_leaves'. This can lead to underfitting. To resolve this warning, pass 'num_leaves' (<=32) in params. Alternatively, pass (max_depth=-1) and just use 'num_leaves' to constrain model complexity.
# [LightGBM] [Info] Start training from score 0.500113
# Training until validation scores don't improve for 10 rounds
# Early stopping, best iteration is:
# [679]	valid_0's l2: 0.0496461
# /home/kouya-takahashi/.local/lib/python3.9/site-packages/lightgbm/engine.py:204: UserWarning: Found `n_estimators` in params. Will use it instead of argument
#   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# [LightGBM] [Warning] Provided parameters constrain tree depth (max_depth=5) without explicitly setting 'num_leaves'. This can lead to underfitting. To resolve this warning, pass 'num_leaves' (<=32) in params. Alternatively, pass (max_depth=-1) and just use 'num_leaves' to constrain model complexity.
# [LightGBM] [Warning] Provided parameters constrain tree depth (max_depth=5) without explicitly setting 'num_leaves'. This can lead to underfitting. To resolve this warning, pass 'num_leaves' (<=32) in params. Alternatively, pass (max_depth=-1) and just use 'num_leaves' to constrain model complexity.
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.002654 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 210
# [LightGBM] [Info] Number of data points in the train set: 1207776, number of used features: 42
# [LightGBM] [Warning] Provided parameters constrain tree depth (max_depth=5) without explicitly setting 'num_leaves'. This can lead to underfitting. To resolve this warning, pass 'num_leaves' (<=32) in params. Alternatively, pass (max_depth=-1) and just use 'num_leaves' to constrain model complexity.
# [LightGBM] [Info] Start training from score 0.500109
# Training until validation scores don't improve for 10 rounds
# Early stopping, best iteration is:
# [720]	valid_0's l2: 0.0496453
# /home/kouya-takahashi/.local/lib/python3.9/site-packages/lightgbm/engine.py:204: UserWarning: Found `n_estimators` in params. Will use it instead of argument
#   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# [LightGBM] [Warning] Provided parameters constrain tree depth (max_depth=5) without explicitly setting 'num_leaves'. This can lead to underfitting. To resolve this warning, pass 'num_leaves' (<=32) in params. Alternatively, pass (max_depth=-1) and just use 'num_leaves' to constrain model complexity.
# [LightGBM] [Warning] Provided parameters constrain tree depth (max_depth=5) without explicitly setting 'num_leaves'. This can lead to underfitting. To resolve this warning, pass 'num_leaves' (<=32) in params. Alternatively, pass (max_depth=-1) and just use 'num_leaves' to constrain model complexity.
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.002617 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 210
# [LightGBM] [Info] Number of data points in the train set: 1208192, number of used features: 42
# [LightGBM] [Warning] Provided parameters constrain tree depth (max_depth=5) without explicitly setting 'num_leaves'. This can lead to underfitting. To resolve this warning, pass 'num_leaves' (<=32) in params. Alternatively, pass (max_depth=-1) and just use 'num_leaves' to constrain model complexity.
# [LightGBM] [Info] Start training from score 0.500073
# Training until validation scores don't improve for 10 rounds
# Early stopping, best iteration is:
# [454]	valid_0's l2: 0.0496563
# ================================================================
# target:  target_agnes_60
# /home/kouya-takahashi/.local/lib/python3.9/site-packages/lightgbm/engine.py:204: UserWarning: Found `n_estimators` in params. Will use it instead of argument
#   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# [LightGBM] [Warning] Provided parameters constrain tree depth (max_depth=5) without explicitly setting 'num_leaves'. This can lead to underfitting. To resolve this warning, pass 'num_leaves' (<=32) in params. Alternatively, pass (max_depth=-1) and just use 'num_leaves' to constrain model complexity.
# [LightGBM] [Warning] Provided parameters constrain tree depth (max_depth=5) without explicitly setting 'num_leaves'. This can lead to underfitting. To resolve this warning, pass 'num_leaves' (<=32) in params. Alternatively, pass (max_depth=-1) and just use 'num_leaves' to constrain model complexity.
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.006885 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 210
# [LightGBM] [Info] Number of data points in the train set: 1208388, number of used features: 42
# [LightGBM] [Warning] Provided parameters constrain tree depth (max_depth=5) without explicitly setting 'num_leaves'. This can lead to underfitting. To resolve this warning, pass 'num_leaves' (<=32) in params. Alternatively, pass (max_depth=-1) and just use 'num_leaves' to constrain model complexity.
# [LightGBM] [Info] Start training from score 0.500115
# Training until validation scores don't improve for 10 rounds
# Early stopping, best iteration is:
# [655]	valid_0's l2: 0.0495574
# /home/kouya-takahashi/.local/lib/python3.9/site-packages/lightgbm/engine.py:204: UserWarning: Found `n_estimators` in params. Will use it instead of argument
#   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# [LightGBM] [Warning] Provided parameters constrain tree depth (max_depth=5) without explicitly setting 'num_leaves'. This can lead to underfitting. To resolve this warning, pass 'num_leaves' (<=32) in params. Alternatively, pass (max_depth=-1) and just use 'num_leaves' to constrain model complexity.
# [LightGBM] [Warning] Provided parameters constrain tree depth (max_depth=5) without explicitly setting 'num_leaves'. This can lead to underfitting. To resolve this warning, pass 'num_leaves' (<=32) in params. Alternatively, pass (max_depth=-1) and just use 'num_leaves' to constrain model complexity.
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.002637 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 210
# [LightGBM] [Info] Number of data points in the train set: 1205900, number of used features: 42
# [LightGBM] [Warning] Provided parameters constrain tree depth (max_depth=5) without explicitly setting 'num_leaves'. This can lead to underfitting. To resolve this warning, pass 'num_leaves' (<=32) in params. Alternatively, pass (max_depth=-1) and just use 'num_leaves' to constrain model complexity.
# [LightGBM] [Info] Start training from score 0.500072
# Training until validation scores don't improve for 10 rounds
# Early stopping, best iteration is:
# [720]	valid_0's l2: 0.049556
# /home/kouya-takahashi/.local/lib/python3.9/site-packages/lightgbm/engine.py:204: UserWarning: Found `n_estimators` in params. Will use it instead of argument
#   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# [LightGBM] [Warning] Provided parameters constrain tree depth (max_depth=5) without explicitly setting 'num_leaves'. This can lead to underfitting. To resolve this warning, pass 'num_leaves' (<=32) in params. Alternatively, pass (max_depth=-1) and just use 'num_leaves' to constrain model complexity.
# [LightGBM] [Warning] Provided parameters constrain tree depth (max_depth=5) without explicitly setting 'num_leaves'. This can lead to underfitting. To resolve this warning, pass 'num_leaves' (<=32) in params. Alternatively, pass (max_depth=-1) and just use 'num_leaves' to constrain model complexity.
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.002799 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 210
# [LightGBM] [Info] Number of data points in the train set: 1207776, number of used features: 42
# [LightGBM] [Warning] Provided parameters constrain tree depth (max_depth=5) without explicitly setting 'num_leaves'. This can lead to underfitting. To resolve this warning, pass 'num_leaves' (<=32) in params. Alternatively, pass (max_depth=-1) and just use 'num_leaves' to constrain model complexity.
# [LightGBM] [Info] Start training from score 0.500060
# Training until validation scores don't improve for 10 rounds
# Early stopping, best iteration is:
# [720]	valid_0's l2: 0.0495561
# /home/kouya-takahashi/.local/lib/python3.9/site-packages/lightgbm/engine.py:204: UserWarning: Found `n_estimators` in params. Will use it instead of argument
#   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# [LightGBM] [Warning] Provided parameters constrain tree depth (max_depth=5) without explicitly setting 'num_leaves'. This can lead to underfitting. To resolve this warning, pass 'num_leaves' (<=32) in params. Alternatively, pass (max_depth=-1) and just use 'num_leaves' to constrain model complexity.
# [LightGBM] [Warning] Provided parameters constrain tree depth (max_depth=5) without explicitly setting 'num_leaves'. This can lead to underfitting. To resolve this warning, pass 'num_leaves' (<=32) in params. Alternatively, pass (max_depth=-1) and just use 'num_leaves' to constrain model complexity.
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.002634 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 210
# [LightGBM] [Info] Number of data points in the train set: 1208192, number of used features: 42
# [LightGBM] [Warning] Provided parameters constrain tree depth (max_depth=5) without explicitly setting 'num_leaves'. This can lead to underfitting. To resolve this warning, pass 'num_leaves' (<=32) in params. Alternatively, pass (max_depth=-1) and just use 'num_leaves' to constrain model complexity.
# [LightGBM] [Info] Start training from score 0.500041
# Training until validation scores don't improve for 10 rounds
# Early stopping, best iteration is:
# [538]	valid_0's l2: 0.0495715

# %%
print(len(models))

for model in models:
    model.visualize_learning_curve()
    model.visualize_feature_importance()
    break
# Out:
# 12

# %% [markdown]
# # Validation

# %%
preds = np.zeros(len(valid))

for model in models:
    preds += model.predict(valid[features]) / len(models)

valid["pred"] = preds
result, per_era_corr, per_era_bmc, per_era_mmc = caluculate_metrics(cfg.dataset_path, valid)
# Out:
# /tmp/ipykernel_148404/4041851832.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   valid["pred"] = preds

# %%
# 損益曲線も wandb上で可視化したかったが log で送ると GUI がバグる
# 総和を連携する

per_era_d = {
    "per_era_corr": per_era_corr,
    "per_era_bmc": per_era_bmc,
    "per_era_mmc": per_era_mmc,
}


for key, val in per_era_d.items():
    print(key)
    # display(val.head())
    total_val = val["pred"].sum()
    wandb.log({
        key: total_val
        # key: []
    })
# Out:
# per_era_corr
# per_era_bmc
# per_era_mmc

# %%
cond = ~valid["target"].isnull()
tmp_valid = valid.loc[cond]
mse = round(mean_squared_error(tmp_valid["pred"], tmp_valid["target"]), 6)

print(mse)
result_d = {key: round(val[0], 6)for key, val in result.to_dict().items()}
n_features = len(features)

result_d["mse"] = mse
result_d["targets"] = targets

print(result_d)
wandb.log(result_d)
# Out:
# 0.049838
# {'corr_mean': 0.012741, 'corr_std': 0.015705, 'corr_shape': 0.811265, 'corr_max_drawdown': 0.069211, 'mmc_mean': -0.003314, 'mmc_std': 0.009242, 'mmc_shape': -0.358597, 'mmc_max_drawdown': 0.034765, 'bmc_mean': 0.00235, 'bmc_std': 0.011765, 'bmc_shape': 0.199714, 'bmc_max_drawdown': 0.315862, 'mse': 0.049838, 'targets': ['target', 'target_agnes_20', 'target_agnes_60']}

# %%
wandb.finish()
# Out:
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>bmc_max_drawdown</td><td>▁▁</td></tr><tr><td>bmc_mean</td><td>▁▁</td></tr><tr><td>bmc_shape</td><td>▁▁</td></tr><tr><td>bmc_std</td><td>▁▁</td></tr><tr><td>corr_max_drawdown</td><td>▁▁</td></tr><tr><td>corr_mean</td><td>▁▁</td></tr><tr><td>corr_shape</td><td>▁▁</td></tr><tr><td>corr_std</td><td>▁▁</td></tr><tr><td>mmc_max_drawdown</td><td>▁▁</td></tr><tr><td>mmc_mean</td><td>▁▁</td></tr><tr><td>mmc_shape</td><td>▁▁</td></tr><tr><td>mmc_std</td><td>▁▁</td></tr><tr><td>mse</td><td>▁▁</td></tr><tr><td>per_era_bmc</td><td>▁</td></tr><tr><td>per_era_corr</td><td>▁</td></tr><tr><td>per_era_mmc</td><td>▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>bmc_max_drawdown</td><td>0.31586</td></tr><tr><td>bmc_mean</td><td>0.00235</td></tr><tr><td>bmc_shape</td><td>0.19971</td></tr><tr><td>bmc_std</td><td>0.01176</td></tr><tr><td>corr_max_drawdown</td><td>0.06921</td></tr><tr><td>corr_mean</td><td>0.01274</td></tr><tr><td>corr_shape</td><td>0.81127</td></tr><tr><td>corr_std</td><td>0.01571</td></tr><tr><td>description</td><td>target_agnes_60 追加</td></tr><tr><td>feature_set</td><td>small</td></tr><tr><td>mmc_max_drawdown</td><td>0.03476</td></tr><tr><td>mmc_mean</td><td>-0.00331</td></tr><tr><td>mmc_shape</td><td>-0.3586</td></tr><tr><td>mmc_std</td><td>0.00924</td></tr><tr><td>mse</td><td>0.04984</td></tr><tr><td>per_era_bmc</td><td>0.531</td></tr><tr><td>per_era_corr</td><td>2.87939</td></tr><tr><td>per_era_mmc</td><td>-0.05303</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">exp021</strong> at: <a href='https://wandb.ai/ko_ya346/numerai_tournament/runs/mz7jqtpr' target="_blank">https://wandb.ai/ko_ya346/numerai_tournament/runs/mz7jqtpr</a><br> View project at: <a href='https://wandb.ai/ko_ya346/numerai_tournament' target="_blank">https://wandb.ai/ko_ya346/numerai_tournament</a><br>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20250223_235856-mz7jqtpr/logs</code>
