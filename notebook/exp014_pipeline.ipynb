# %% [markdown]
# # 新しいパイプライン
# - 複数 target でアンサンブル
# - valid の一部を学習に使用する
# - era の mod 4 毎に学習

# %%
# %load_ext autoreload
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
# %autoreload 2

import os
import sys
import json
import gc
import pickle 


from numerapi import NumerAPI
from numerai_tools.scoring import numerai_corr, correlation_contribution

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

import lightgbm as lgb

sys.path.append("../")
from src.model import MLModel, LightGBMModel
from src.validation import caluculate_metrics

# %% [markdown]
# # Config

# %%
class cfg:
    exp = "exp014"
    dataset_path = "../dataset/v5.0"
    feature_set = "medium"
    valid_ratio = 0.2
    
    model_params = {
        "objective": "regression",
        "metric": "l2",
        "n_estimators": 2000,
        "max_depth": 5,
        "learning_rate": 0.01,
        "feature_fraction": 0.1,
        "seed": 42,
    }

# %%
# 実験用フォルダ作成    
os.makedirs(cfg.exp, exist_ok=True)

# 辞書形式に変換して保存 (推論時に使用する)
cfg_dict = {attr: getattr(cfg, attr) for attr in dir(cfg) if not attr.startswith("__") and not callable(getattr(cfg, attr))}
config_file = os.path.join(cfg.exp, "training_config.json")
with open(config_file, "w") as f:
    json.dump(cfg_dict, f, indent=4)

with open(f"{cfg.dataset_path}/features.json", "r") as f:
    feature_metadata = json.load(f)

# print(feature_metadata.keys())
feature_sets = feature_metadata["feature_sets"]
# print(feature_sets.keys())
feature_set = feature_sets[cfg.feature_set][:80]
print(f"feature col length: {len(feature_set)}")


targets = feature_metadata["targets"]
targets = ["target", "target_agnes_20"]
# Out:
# feature col length: 80

# %% [markdown]
# # Load Data

# %%
train = pd.read_parquet(
    f"{cfg.dataset_path}/train.parquet",
    columns=["era"] + feature_set + targets
)

valid = pd.read_parquet(
    f"{cfg.dataset_path}/validation.parquet",
    columns=["era"] + feature_set + targets
    
)

print(train.shape)
display(train.head(2))

print(valid.shape)
display(valid.head(2))
# Out:
# (2746270, 83)
#                    era  feature_able_deprived_nona  \
# id
# n0007b5abb0c3a25  0001                           1
# n003bba8a98662e4  0001                           3
#
#                   feature_ablest_inflexional_egeria  \
# id
# n0007b5abb0c3a25                                  2
# n003bba8a98662e4                                  2
#
#                   feature_absorbable_hyperalgesic_mode  \
# id
# n0007b5abb0c3a25                                     3
# n003bba8a98662e4                                     4
#
#                   feature_accoutered_revolute_vexillology  \
# id
# n0007b5abb0c3a25                                        2
# n003bba8a98662e4                                        1
#
#                   feature_acetose_crackerjack_needlecraft  \
# id
# n0007b5abb0c3a25                                        3
# n003bba8a98662e4                                        0
#
#                   feature_acheulian_conserving_output  \
# id
# n0007b5abb0c3a25                                    2
# n003bba8a98662e4                                    2
#
#                   feature_acronychal_bilobate_stevenage  \
# id
# n0007b5abb0c3a25                                      2
# n003bba8a98662e4                                      3
#
#                   feature_acrylic_gallic_wine  \
# id
# n0007b5abb0c3a25                            2
# n003bba8a98662e4                            2
#
#                   feature_adminicular_shod_levant  ...  \
# id                                                 ...
# n0007b5abb0c3a25                                3  ...
# n003bba8a98662e4                                4  ...
#
#                   feature_catechetical_paragogical_accouterment  \
# id
# n0007b5abb0c3a25                                              0
# n003bba8a98662e4                                              3
#
#                   feature_celibate_wayworn_cosmism  \
# id
# n0007b5abb0c3a25                                 2
# n003bba8a98662e4                                 2
#
#                   feature_cephalate_unfine_molality  \
# id
# n0007b5abb0c3a25                                  2
# n003bba8a98662e4                                  2
#
#                   feature_cervical_swell_tunisia  \
# id
# n0007b5abb0c3a25                               3
# n003bba8a98662e4                               4
#
#                   feature_champion_arabic_teetotum  \
# id
# n0007b5abb0c3a25                                 2
# n003bba8a98662e4                                 1
#
#                   feature_chaste_disqualifying_intermodulation  \
# id
# n0007b5abb0c3a25                                             2
# n003bba8a98662e4                                             2
#
#                   feature_chattier_tight_academic  \
# id
# n0007b5abb0c3a25                                3
# n003bba8a98662e4                                3
#
#                   feature_cheeky_african_waikiki  target  target_agnes_20
# id
# n0007b5abb0c3a25                               2    0.25             0.25
# n003bba8a98662e4                               2    0.25             0.25
#
# [2 rows x 83 columns]
# (3577827, 83)
#                    era  feature_able_deprived_nona  \
# id
# n000101811a8a843  0575                           2
# n001e1318d5072ac  0575                           0
#
#                   feature_ablest_inflexional_egeria  \
# id
# n000101811a8a843                                  1
# n001e1318d5072ac                                  2
#
#                   feature_absorbable_hyperalgesic_mode  \
# id
# n000101811a8a843                                     2
# n001e1318d5072ac                                     2
#
#                   feature_accoutered_revolute_vexillology  \
# id
# n000101811a8a843                                        4
# n001e1318d5072ac                                        3
#
#                   feature_acetose_crackerjack_needlecraft  \
# id
# n000101811a8a843                                        0
# n001e1318d5072ac                                        2
#
#                   feature_acheulian_conserving_output  \
# id
# n000101811a8a843                                    4
# n001e1318d5072ac                                    3
#
#                   feature_acronychal_bilobate_stevenage  \
# id
# n000101811a8a843                                      0
# n001e1318d5072ac                                      0
#
#                   feature_acrylic_gallic_wine  \
# id
# n000101811a8a843                            0
# n001e1318d5072ac                            0
#
#                   feature_adminicular_shod_levant  ...  \
# id                                                 ...
# n000101811a8a843                                2  ...
# n001e1318d5072ac                                4  ...
#
#                   feature_catechetical_paragogical_accouterment  \
# id
# n000101811a8a843                                              0
# n001e1318d5072ac                                              4
#
#                   feature_celibate_wayworn_cosmism  \
# id
# n000101811a8a843                                 0
# n001e1318d5072ac                                 3
#
#                   feature_cephalate_unfine_molality  \
# id
# n000101811a8a843                                  0
# n001e1318d5072ac                                  3
#
#                   feature_cervical_swell_tunisia  \
# id
# n000101811a8a843                               0
# n001e1318d5072ac                               4
#
#                   feature_champion_arabic_teetotum  \
# id
# n000101811a8a843                                 4
# n001e1318d5072ac                                 3
#
#                   feature_chaste_disqualifying_intermodulation  \
# id
# n000101811a8a843                                             0
# n001e1318d5072ac                                             3
#
#                   feature_chattier_tight_academic  \
# id
# n000101811a8a843                                2
# n001e1318d5072ac                                4
#
#                   feature_cheeky_african_waikiki  target  target_agnes_20
# id
# n000101811a8a843                               3    0.75             0.75
# n001e1318d5072ac                               1    0.00             0.00
#
# [2 rows x 83 columns]

# %% [markdown]
# # Preprocess

# %%
# 学習データを増やす (train, valid を合体してから分ける)
print(train.shape, valid.shape)

data = pd.concat([train, valid])
display(data.tail())

# era 単位で分ける
all_era = data["era"].unique()
n_idx = int(len(all_era) * (1 - cfg.valid_ratio))
print(data.shape)
print(n_idx)

train_era = all_era[:n_idx]
cond_train = data["era"].isin(train_era)
train, valid = data.loc[cond_train], data.loc[~cond_train]

print(train.shape, valid.shape)
# Out:
# (2746270, 83) (3577827, 83)
#                    era  feature_able_deprived_nona  \
# id
# nffce425c89dc5da  1153                           0
# nffd4e7b55827375  1153                           1
# nffea643830509bf  1153                           2
# nffea66c53d0aebe  1153                           4
# nfff2966f1f157af  1153                           2
#
#                   feature_ablest_inflexional_egeria  \
# id
# nffce425c89dc5da                                  4
# nffd4e7b55827375                                  4
# nffea643830509bf                                  3
# nffea66c53d0aebe                                  0
# nfff2966f1f157af                                  0
#
#                   feature_absorbable_hyperalgesic_mode  \
# id
# nffce425c89dc5da                                     2
# nffd4e7b55827375                                     0
# nffea643830509bf                                     4
# nffea66c53d0aebe                                     0
# nfff2966f1f157af                                     0
#
#                   feature_accoutered_revolute_vexillology  \
# id
# nffce425c89dc5da                                        4
# nffd4e7b55827375                                        1
# nffea643830509bf                                        2
# nffea66c53d0aebe                                        2
# nfff2966f1f157af                                        3
#
#                   feature_acetose_crackerjack_needlecraft  \
# id
# nffce425c89dc5da                                        2
# nffd4e7b55827375                                        0
# nffea643830509bf                                        2
# nffea66c53d0aebe                                        2
# nfff2966f1f157af                                        4
#
#                   feature_acheulian_conserving_output  \
# id
# nffce425c89dc5da                                    2
# nffd4e7b55827375                                    0
# nffea643830509bf                                    1
# nffea66c53d0aebe                                    2
# nfff2966f1f157af                                    4
#
#                   feature_acronychal_bilobate_stevenage  \
# id
# nffce425c89dc5da                                      1
# nffd4e7b55827375                                      4
# nffea643830509bf                                      4
# nffea66c53d0aebe                                      1
# nfff2966f1f157af                                      3
#
#                   feature_acrylic_gallic_wine  \
# id
# nffce425c89dc5da                            4
# nffd4e7b55827375                            4
# nffea643830509bf                            2
# nffea66c53d0aebe                            0
# nfff2966f1f157af                            1
#
#                   feature_adminicular_shod_levant  ...  \
# id                                                 ...
# nffce425c89dc5da                                1  ...
# nffd4e7b55827375                                4  ...
# nffea643830509bf                                4  ...
# nffea66c53d0aebe                                2  ...
# nfff2966f1f157af                                4  ...
#
#                   feature_catechetical_paragogical_accouterment  \
# id
# nffce425c89dc5da                                              0
# nffd4e7b55827375                                              4
# nffea643830509bf                                              4
# nffea66c53d0aebe                                              2
# nfff2966f1f157af                                              4
#
#                   feature_celibate_wayworn_cosmism  \
# id
# nffce425c89dc5da                                 2
# nffd4e7b55827375                                 0
# nffea643830509bf                                 1
# nffea66c53d0aebe                                 2
# nfff2966f1f157af                                 0
#
#                   feature_cephalate_unfine_molality  \
# id
# nffce425c89dc5da                                  2
# nffd4e7b55827375                                  4
# nffea643830509bf                                  2
# nffea66c53d0aebe                                  1
# nfff2966f1f157af                                  3
#
#                   feature_cervical_swell_tunisia  \
# id
# nffce425c89dc5da                               4
# nffd4e7b55827375                               0
# nffea643830509bf                               0
# nffea66c53d0aebe                               3
# nfff2966f1f157af                               0
#
#                   feature_champion_arabic_teetotum  \
# id
# nffce425c89dc5da                                 4
# nffd4e7b55827375                                 4
# nffea643830509bf                                 4
# nffea66c53d0aebe                                 2
# nfff2966f1f157af                                 4
#
#                   feature_chaste_disqualifying_intermodulation  \
# id
# nffce425c89dc5da                                             2
# nffd4e7b55827375                                             4
# nffea643830509bf                                             1
# nffea66c53d0aebe                                             2
# nfff2966f1f157af                                             0
#
#                   feature_chattier_tight_academic  \
# id
# nffce425c89dc5da                                0
# nffd4e7b55827375                                0
# nffea643830509bf                                4
# nffea66c53d0aebe                                1
# nfff2966f1f157af                                0
#
#                   feature_cheeky_african_waikiki  target  target_agnes_20
# id
# nffce425c89dc5da                               1     NaN              NaN
# nffd4e7b55827375                               4     NaN              NaN
# nffea643830509bf                               4     NaN              NaN
# nffea66c53d0aebe                               2     NaN              NaN
# nfff2966f1f157af                               4     NaN              NaN
#
# [5 rows x 83 columns]
# (6324097, 83)
# 922
# (4817566, 83) (1506531, 83)

# %%
train["era_int"] = train["era"].astype(int)
# Out:
# /tmp/ipykernel_17380/1731592198.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train["era_int"] = train["era"].astype(int)

# %% [markdown]
# # Training

# %%
features = feature_set

# %%
models = []

for target in targets:
    print("=" * 64)
    print("target: ", target)
    for i in range(4):
        cond_train = (train["era_int"] % 4 == i) & (~train[target].isnull())
        cond_valid = ~valid[target].isnull()
        tmp_train = train.loc[cond_train]
        tmp_valid = valid.loc[cond_valid]

        model = LightGBMModel(
            model_params=cfg.model_params,
        )
        model.train(
            tmp_train[features],
            tmp_train[target],
            eval_set=(tmp_valid[features], tmp_valid[target]),
            early_stopping_rounds=10
        )
        models.append(model)
        model.save_model(os.path.join(cfg.exp, f"model_{i}_{target}.pkl"))

with open(os.path.join(cfg.exp, "feature.pkl"), "wb") as f:
     pickle.dump(features, f)
# Out:
# (4817566, 84) (1506531, 83)
# (4817566, 84) (1475913, 83)
# ================================================================
# target:  target
# /home/kouya-takahashi/.local/lib/python3.9/site-packages/lightgbm/engine.py:204: UserWarning: Found `n_estimators` in params. Will use it instead of argument
#   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# [LightGBM] [Warning] Provided parameters constrain tree depth (max_depth=5) without explicitly setting 'num_leaves'. This can lead to underfitting. To resolve this warning, pass 'num_leaves' (<=32) in params. Alternatively, pass (max_depth=-1) and just use 'num_leaves' to constrain model complexity.
# [LightGBM] [Warning] Provided parameters constrain tree depth (max_depth=5) without explicitly setting 'num_leaves'. This can lead to underfitting. To resolve this warning, pass 'num_leaves' (<=32) in params. Alternatively, pass (max_depth=-1) and just use 'num_leaves' to constrain model complexity.
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.003714 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 400
# [LightGBM] [Info] Number of data points in the train set: 1202054, number of used features: 80
# [LightGBM] [Warning] Provided parameters constrain tree depth (max_depth=5) without explicitly setting 'num_leaves'. This can lead to underfitting. To resolve this warning, pass 'num_leaves' (<=32) in params. Alternatively, pass (max_depth=-1) and just use 'num_leaves' to constrain model complexity.
# [LightGBM] [Info] Start training from score 0.500031
# Training until validation scores don't improve for 10 rounds
# Early stopping, best iteration is:
# [384]	valid_0's l2: 0.0498282
# /home/kouya-takahashi/.local/lib/python3.9/site-packages/lightgbm/engine.py:204: UserWarning: Found `n_estimators` in params. Will use it instead of argument
#   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# [LightGBM] [Warning] Provided parameters constrain tree depth (max_depth=5) without explicitly setting 'num_leaves'. This can lead to underfitting. To resolve this warning, pass 'num_leaves' (<=32) in params. Alternatively, pass (max_depth=-1) and just use 'num_leaves' to constrain model complexity.
# [LightGBM] [Warning] Provided parameters constrain tree depth (max_depth=5) without explicitly setting 'num_leaves'. This can lead to underfitting. To resolve this warning, pass 'num_leaves' (<=32) in params. Alternatively, pass (max_depth=-1) and just use 'num_leaves' to constrain model complexity.
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.003721 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 400
# [LightGBM] [Info] Number of data points in the train set: 1205900, number of used features: 80
# [LightGBM] [Warning] Provided parameters constrain tree depth (max_depth=5) without explicitly setting 'num_leaves'. This can lead to underfitting. To resolve this warning, pass 'num_leaves' (<=32) in params. Alternatively, pass (max_depth=-1) and just use 'num_leaves' to constrain model complexity.
# [LightGBM] [Info] Start training from score 0.500020
# Training until validation scores don't improve for 10 rounds
# Early stopping, best iteration is:
# [418]	valid_0's l2: 0.0498293
# /home/kouya-takahashi/.local/lib/python3.9/site-packages/lightgbm/engine.py:204: UserWarning: Found `n_estimators` in params. Will use it instead of argument
#   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# [LightGBM] [Warning] Provided parameters constrain tree depth (max_depth=5) without explicitly setting 'num_leaves'. This can lead to underfitting. To resolve this warning, pass 'num_leaves' (<=32) in params. Alternatively, pass (max_depth=-1) and just use 'num_leaves' to constrain model complexity.
# [LightGBM] [Warning] Provided parameters constrain tree depth (max_depth=5) without explicitly setting 'num_leaves'. This can lead to underfitting. To resolve this warning, pass 'num_leaves' (<=32) in params. Alternatively, pass (max_depth=-1) and just use 'num_leaves' to constrain model complexity.
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.007165 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 400
# [LightGBM] [Info] Number of data points in the train set: 1207776, number of used features: 80
# [LightGBM] [Warning] Provided parameters constrain tree depth (max_depth=5) without explicitly setting 'num_leaves'. This can lead to underfitting. To resolve this warning, pass 'num_leaves' (<=32) in params. Alternatively, pass (max_depth=-1) and just use 'num_leaves' to constrain model complexity.
# [LightGBM] [Info] Start training from score 0.500018
# Training until validation scores don't improve for 10 rounds
# Early stopping, best iteration is:
# [395]	valid_0's l2: 0.0498293
# /home/kouya-takahashi/.local/lib/python3.9/site-packages/lightgbm/engine.py:204: UserWarning: Found `n_estimators` in params. Will use it instead of argument
#   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# [LightGBM] [Warning] Provided parameters constrain tree depth (max_depth=5) without explicitly setting 'num_leaves'. This can lead to underfitting. To resolve this warning, pass 'num_leaves' (<=32) in params. Alternatively, pass (max_depth=-1) and just use 'num_leaves' to constrain model complexity.
# [LightGBM] [Warning] Provided parameters constrain tree depth (max_depth=5) without explicitly setting 'num_leaves'. This can lead to underfitting. To resolve this warning, pass 'num_leaves' (<=32) in params. Alternatively, pass (max_depth=-1) and just use 'num_leaves' to constrain model complexity.
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.006464 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 400
# [LightGBM] [Info] Number of data points in the train set: 1201836, number of used features: 80
# [LightGBM] [Warning] Provided parameters constrain tree depth (max_depth=5) without explicitly setting 'num_leaves'. This can lead to underfitting. To resolve this warning, pass 'num_leaves' (<=32) in params. Alternatively, pass (max_depth=-1) and just use 'num_leaves' to constrain model complexity.
# [LightGBM] [Info] Start training from score 0.500023
# Training until validation scores don't improve for 10 rounds
# Early stopping, best iteration is:
# [331]	valid_0's l2: 0.0498304
# ================================================================
# target:  target_agnes_20
# /home/kouya-takahashi/.local/lib/python3.9/site-packages/lightgbm/engine.py:204: UserWarning: Found `n_estimators` in params. Will use it instead of argument
#   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# [LightGBM] [Warning] Provided parameters constrain tree depth (max_depth=5) without explicitly setting 'num_leaves'. This can lead to underfitting. To resolve this warning, pass 'num_leaves' (<=32) in params. Alternatively, pass (max_depth=-1) and just use 'num_leaves' to constrain model complexity.
# [LightGBM] [Warning] Provided parameters constrain tree depth (max_depth=5) without explicitly setting 'num_leaves'. This can lead to underfitting. To resolve this warning, pass 'num_leaves' (<=32) in params. Alternatively, pass (max_depth=-1) and just use 'num_leaves' to constrain model complexity.
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.003729 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 400
# [LightGBM] [Info] Number of data points in the train set: 1202054, number of used features: 80
# [LightGBM] [Warning] Provided parameters constrain tree depth (max_depth=5) without explicitly setting 'num_leaves'. This can lead to underfitting. To resolve this warning, pass 'num_leaves' (<=32) in params. Alternatively, pass (max_depth=-1) and just use 'num_leaves' to constrain model complexity.
# [LightGBM] [Info] Start training from score 0.500054
# Training until validation scores don't improve for 10 rounds
# Early stopping, best iteration is:
# [552]	valid_0's l2: 0.0496332
# /home/kouya-takahashi/.local/lib/python3.9/site-packages/lightgbm/engine.py:204: UserWarning: Found `n_estimators` in params. Will use it instead of argument
#   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# [LightGBM] [Warning] Provided parameters constrain tree depth (max_depth=5) without explicitly setting 'num_leaves'. This can lead to underfitting. To resolve this warning, pass 'num_leaves' (<=32) in params. Alternatively, pass (max_depth=-1) and just use 'num_leaves' to constrain model complexity.
# [LightGBM] [Warning] Provided parameters constrain tree depth (max_depth=5) without explicitly setting 'num_leaves'. This can lead to underfitting. To resolve this warning, pass 'num_leaves' (<=32) in params. Alternatively, pass (max_depth=-1) and just use 'num_leaves' to constrain model complexity.
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.003715 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 400
# [LightGBM] [Info] Number of data points in the train set: 1205900, number of used features: 80
# [LightGBM] [Warning] Provided parameters constrain tree depth (max_depth=5) without explicitly setting 'num_leaves'. This can lead to underfitting. To resolve this warning, pass 'num_leaves' (<=32) in params. Alternatively, pass (max_depth=-1) and just use 'num_leaves' to constrain model complexity.
# [LightGBM] [Info] Start training from score 0.500113
# Training until validation scores don't improve for 10 rounds
# Early stopping, best iteration is:
# [640]	valid_0's l2: 0.04963
# /home/kouya-takahashi/.local/lib/python3.9/site-packages/lightgbm/engine.py:204: UserWarning: Found `n_estimators` in params. Will use it instead of argument
#   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# [LightGBM] [Warning] Provided parameters constrain tree depth (max_depth=5) without explicitly setting 'num_leaves'. This can lead to underfitting. To resolve this warning, pass 'num_leaves' (<=32) in params. Alternatively, pass (max_depth=-1) and just use 'num_leaves' to constrain model complexity.
# [LightGBM] [Warning] Provided parameters constrain tree depth (max_depth=5) without explicitly setting 'num_leaves'. This can lead to underfitting. To resolve this warning, pass 'num_leaves' (<=32) in params. Alternatively, pass (max_depth=-1) and just use 'num_leaves' to constrain model complexity.
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.007207 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 400
# [LightGBM] [Info] Number of data points in the train set: 1207776, number of used features: 80
# [LightGBM] [Warning] Provided parameters constrain tree depth (max_depth=5) without explicitly setting 'num_leaves'. This can lead to underfitting. To resolve this warning, pass 'num_leaves' (<=32) in params. Alternatively, pass (max_depth=-1) and just use 'num_leaves' to constrain model complexity.
# [LightGBM] [Info] Start training from score 0.500109
# Training until validation scores don't improve for 10 rounds
# Early stopping, best iteration is:
# [640]	valid_0's l2: 0.0496297
# /home/kouya-takahashi/.local/lib/python3.9/site-packages/lightgbm/engine.py:204: UserWarning: Found `n_estimators` in params. Will use it instead of argument
#   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# [LightGBM] [Warning] Provided parameters constrain tree depth (max_depth=5) without explicitly setting 'num_leaves'. This can lead to underfitting. To resolve this warning, pass 'num_leaves' (<=32) in params. Alternatively, pass (max_depth=-1) and just use 'num_leaves' to constrain model complexity.
# [LightGBM] [Warning] Provided parameters constrain tree depth (max_depth=5) without explicitly setting 'num_leaves'. This can lead to underfitting. To resolve this warning, pass 'num_leaves' (<=32) in params. Alternatively, pass (max_depth=-1) and just use 'num_leaves' to constrain model complexity.
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.008861 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 400
# [LightGBM] [Info] Number of data points in the train set: 1201836, number of used features: 80
# [LightGBM] [Warning] Provided parameters constrain tree depth (max_depth=5) without explicitly setting 'num_leaves'. This can lead to underfitting. To resolve this warning, pass 'num_leaves' (<=32) in params. Alternatively, pass (max_depth=-1) and just use 'num_leaves' to constrain model complexity.
# [LightGBM] [Info] Start training from score 0.500072
# Training until validation scores don't improve for 10 rounds
# Early stopping, best iteration is:
# [645]	valid_0's l2: 0.0496357

# %%
print(len(models))

for model in models:
    model.visualize_learning_curve()
    model.visualize_feature_importance()
    break
# Out:
# 8

# %% [markdown]
# # Validation

# %%
preds = np.zeros(len(valid))

for model in models:
    preds += model.predict(valid[features]) / len(models)

valid["pred"] = preds
caluculate_metrics(cfg.dataset_path, valid)
# Out:
# (   corr_mean  corr_std  corr_shape  corr_max_drawdown  mmc_mean   mmc_std  \
#  0    0.01244  0.019515    0.637456           0.162183  0.008828  0.006772
#
#     mmc_shape  mmc_max_drawdown  bmc_mean   bmc_std  bmc_shape  \
#  0   1.303702          0.008161  0.001134  0.013946   0.081312
#
#     bmc_max_drawdown
#  0          0.549767  ,
#            pred
#  era
#  0923  0.027909
#  0924  0.042971
#  0925  0.030157
#  0926  0.033979
#  0927  0.020169
#  ...        ...
#  1144  0.030595
#  1145  0.019979
#  1146  0.015518
#  1147  0.014227
#  1148  0.024647
#
#  [226 rows x 1 columns],
#            pred
#  era
#  0923  0.018644
#  0924  0.024840
#  0925  0.010250
#  0926  0.011611
#  0927  0.005204
#  ...        ...
#  1144  0.013243
#  1145  0.012413
#  1146  0.018020
#  1147  0.007723
#  1148  0.015955
#
#  [226 rows x 1 columns],
#            pred
#  era
#  1133  0.017020
#  1134  0.013821
#  1135  0.013797
#  1136  0.006034
#  1137 -0.004029
#  1138 -0.004133
#  1139  0.000132
#  1140  0.010680
#  1141  0.014374
#  1142  0.014682
#  1143  0.013687
#  1144  0.008190
#  1145  0.008110
#  1146  0.013083
#  1147  0.003340
#  1148  0.012466)
